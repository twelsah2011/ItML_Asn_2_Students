# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import SGDRegressor
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV


from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.tree import ExtraTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression

# %% [markdown]
# # Assignment 2 - Regression
# ### Predict the TOTAL COMPENSATION for this year.
#
# The data file provided is a salary survey for tech workers in Europe. We want to predict the total amount of compensation they bring in each year, based off of the details of their work.
#
# Some notes that will be important:
# <ul>
#     <li>The total compensation will need to be constructed, there is a column for salary, "Yearly brutto salary (without bonus and stocks) in EUR", as well as a column for bonus compensation, "Yearly bonus + stocks in EUR".
#     <li>Some categorical variables will need some work, and there isn't generally an exact answer. The main concern is things with categories that have a bunch of values with a very small count. For example, if there is only 1 person in City X, then that value likely needs to be addressed. We don't want it encoded into a new column of one 1 and thousands of 0s.
#     <li>There is an article exploring some of the data here: https://www.asdcode.de/2021/01/it-salary-survey-december-2020.html
#     <li>Imputation and a bit of data manipulation will be required.
#     <li>Use any regression method you'd like. Some ones are closely related to what we've done, you may want to look at them, e.g. ExtraTreesRegressor.
#     <li>Initial accurracy, and potentially final accuracy, may not be great. When I made a plain model will little optimization the errors were large and the R2 was low. There is lots of room for optimization.
#     <li>Research challenge - try some work on the target, look into TransformedTargetRegressor and see if that helps. Recall in stats when we had skewed distributions... Maybe it helps, maybe it doesn't.
#     <li>EDA and data prep are up to you - you'll probably need to do a little exploring to figure out what cleanup is needed. When I did it, I did things kind of iteratively when I did it. For example, look at the value counts, figure out how to treat the different categories, clean something up, look at the results, potentially repeat if needed. After you figure out what needs to be done, you may be able to take some of those steps and incorporate them into a pipeline to be cleaner....
#     <li><b>CRITICAL - Please make sure your code runs with RUN ALL. It should load the data that you're given, do all the processing, and spit out results. Comment out or remove anything that you've cleaned up and don't need - e.g. if you scaled a value manually, then moved that into a pipeline, don't leave the original scaling code active when the file is run.</b>
# </ul>
#
# ### Details and Deliverables
#
# You'll need to build code to produce the predictions. In particular, there's a few things that'll be marked:
# <ul>
#     <li>Please add a markdown cell at the bottom, and put in a few notes addressing the following:
#     <ul>
#         <li> Accuracy of your models with/without feature selection. Include both train/test for each. Please use R2 and RMSE.
#         <li> Feature Selection - Please identify what you did for feature selection. No need for a long explaination, something along the lines of "I did X, and the result was that 4 features were removed". Try at least 2 things.
#         <li> Hyperparameter Changes / Grid Search Improvements. What did you try, and why. Similar explaination to above, short.
#         <li> Overall this section should be roughly as long as this intro block - just outline what the results were, what you did to improve, and the results after.
#         <li> If you could use titles/bullet points I'd really appreciate it.
#     </ul>
#     <li>Grade Breakdown:
#     <ul>
#         <li> Code is readable, there are comments: 20%
#         <li> Explaination as defined above: 60% (20% each point)
#         <li> Accuracy: 20% As compared to everyone else. This will be generously graded, I won't be surprised if overall accuracy is low for most people.
#     </ul>
# </ul>

# %%
#Load Data
df = pd.read_csv("data/Euro_Salary.csv")
df.sample(3)
# Out:
#                 Timestamp   Age  Gender    City            Position   \
# 1190  22/12/2020 17:11:31  37.0    Male  Aachen          QA Engineer
# 235   24/11/2020 13:55:19  32.0    Male  Berlin  Engineering Manager
# 1209  28/12/2020 22:24:47  24.0  Female  Munich    Software Engineer
#
#      Total years of experience Years of experience in Germany Seniority level  \
# 1190                        15                              1          Senior
# 235                          9                              5            Lead
# 1209            less than year                 less than year         student
#
#      Your main technology / programming language  \
# 1190                                      Python
# 235                                          NaN
# 1209               Python, database technologies
#
#      Other technologies/programming languages you use often  \
# 1190                                                NaN
# 235   PHP, Javascript / Typescript, .NET, SQL, Googl...
# 1209                     Python, Java / Scala, SQL, AWS
#
#       Yearly brutto salary (without bonus and stocks) in EUR  \
# 1190                                            70000.0
# 235                                             95000.0
# 1209                                            16320.0
#
#      Yearly bonus + stocks in EUR Number of vacation days   Employment status  \
# 1190                         7000                      28  Full-time employee
# 235                        140000                     365  Full-time employee
# 1209                        16320                      10  Part-time employee
#
#        Сontract duration Main language at work Company size Company type
# 1190  Unlimited contract               English     101-1000      Product
# 235   Unlimited contract               English        1000+      Product
# 1209  Unlimited contract               English        11-50      Startup

# %% [markdown]
# drop timestamp column first, and make functions for missing value counts and replacement of NaN values.

# %%
df.drop(columns = {'Timestamp'}, inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 17 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Age                                                     1226 non-null   float64
#  1   Gender                                                  1243 non-null   object
#  2   City                                                    1253 non-null   object
#  3   Position                                                1247 non-null   object
#  4   Total years of experience                               1237 non-null   object
#  5   Years of experience in Germany                          1221 non-null   object
#  6   Seniority level                                         1241 non-null   object
#  7   Your main technology / programming language             1126 non-null   object
#  8   Other technologies/programming languages you use often  1096 non-null   object
#  9   Yearly brutto salary (without bonus and stocks) in EUR  1253 non-null   float64
#  10  Yearly bonus + stocks in EUR                            829 non-null    object
#  11  Number of vacation days                                 1185 non-null   object
#  12  Employment status                                       1236 non-null   object
#  13  Сontract duration                                       1224 non-null   object
#  14  Main language at work                                   1237 non-null   object
#  15  Company size                                            1235 non-null   object
#  16  Company type                                            1228 non-null   object
# dtypes: float64(2), object(15)
# memory usage: 166.5+ KB

# %%
def replace_low_freq(d, col, threshold=10, replacement='other'):
    value_counts = d[col].value_counts() # Specific column 
    to_remove = value_counts[value_counts <= threshold].index
    tmp = d[col].replace(to_replace=to_remove, value=replacement)
    return tmp

# %%
def missing_values() :
    for c in df.columns :
        count = df[c].isnull().sum()
        print(f"missing values in column '{c}': {count}")

# %%
def commas(df, columns) :
    df[columns] = pd.to_numeric(df[columns], downcast = 'float', errors = 'coerce')
    df[columns].replace(',', '.', inplace = True)
    df[columns].apply(lambda n : f'{n : ,.1f}')
    print(df[columns].sample(5))

# %%
# Construct Target by adding salary and bonus. 
df["Yearly bonus + stocks in EUR"] = pd.to_numeric(df["Yearly bonus + stocks in EUR"], downcast="float", errors="coerce")
df["Yearly bonus + stocks in EUR"].fillna(0, inplace=True)
df['total salary'] = df["Yearly brutto salary (without bonus and stocks) in EUR"] + df["Yearly bonus + stocks in EUR"]
df.drop(columns={"Yearly brutto salary (without bonus and stocks) in EUR", "Yearly bonus + stocks in EUR"}, inplace=True)
df.sample(3)
# Out:
#       Age  Gender    City          Position  Total years of experience  \
# 814  35.0  Female  Berlin    Product Manager                        13
# 635  33.0    Male  Berlin             DevOps                         8
# 681  32.0    Male  Berlin  Backend Developer                        10
#
#     Years of experience in Germany Seniority level  \
# 814                              6          Senior
# 635                              3          Senior
# 681                              3            Lead
#
#     Your main technology / programming language  \
# 814                                         NaN
# 635                                         AWS
# 681                                        Ruby
#
#     Other technologies/programming languages you use often  \
# 814                                                NaN
# 635                    Python, AWS, Kubernetes, Docker
# 681  Python, Javascript / Typescript, Ruby, SQL, AW...
#
#     Number of vacation days   Employment status   Сontract duration  \
# 814                      26  Full-time employee  Unlimited contract
# 635                      30  Full-time employee  Unlimited contract
# 681                      28  Full-time employee  Unlimited contract
#
#     Main language at work Company size Company type  total salary
# 814               English     101-1000      Product       85000.0
# 635               English        1000+      service       76000.0
# 681               English       51-100      Product       80000.0

# %% [markdown]
# <b> missing values check: </b>
#
# 1. check missing values in the Age column, and compare them with other columns. if the missing values also appear with other columns, it is better to drop those 27 rows.
# 2. check the total salary plot to check outliers. slicing the value up to 250000.00.
# 3. plot the gender column, and change diverse to others. replace the 3 missing values with 'Other'.
# 4. check the Seniority level column and sort them to others that count under 10.
# 5. 'Total years of experience' and 'Years of experience in Germany' columns had error symbols for floating numbers. They were converted from ',' to '.'. Then changed the type to float64 and replaced by NaN values to 0.
# 6. 'Main language at work' column sorting into 5 language categories.
# 7. 'Company types' column sorting into 4 categories and sorting them to others that count under 10.
# 8. grouping by value count that under 10 types of company types into others and replace NaN values to an unknown type.
# 9. converted 0 to the rest of the columns that have missing values.
# 10. drop 'Number of vacation days', 'Employment status', 'Сontract duration' columns, they are not very helpful for the prediction.
# 11. combined 'Your main technology / programming language' and 'Other technologies/programming languages you use often' columns into 1 column of programming language. Replace NaN values to an unknown type.

# %%
missing_values()
# Out:
# missing values in column 'Age': 27
# missing values in column 'Gender': 10
# missing values in column 'City': 0
# missing values in column 'Position ': 6
# missing values in column 'Total years of experience': 16
# missing values in column 'Years of experience in Germany': 32
# missing values in column 'Seniority level': 12
# missing values in column 'Your main technology / programming language': 127
# missing values in column 'Other technologies/programming languages you use often': 157
# missing values in column 'Number of vacation days': 68
# missing values in column 'Employment status': 17
# missing values in column 'Сontract duration': 29
# missing values in column 'Main language at work': 16
# missing values in column 'Company size': 18
# missing values in column 'Company type': 25
# missing values in column 'total salary': 0

# %%
df[df['Age'].isnull()][['Total years of experience', 'Seniority level', 'Employment status', 'Company type']]
# Out:
#      Total years of experience Seniority level           Employment status  \
# 11                          25          Senior  Self-employed (freelancer)
# 12                         NaN            Lead          Full-time employee
# 28                          14          Senior          Full-time employee
# 55                         NaN          Senior          Full-time employee
# 113                          6          Middle          Full-time employee
# 300                        7.5          Middle          Full-time employee
# 330                          2          Middle          Full-time employee
# 340                        NaN          Senior          Full-time employee
# 365                          9            Lead          Full-time employee
# 374                          8            Lead          Part-time employee
# 418                          4          Middle          Full-time employee
# 473                        NaN             NaN                         NaN
# 529                         15          Senior          Full-time employee
# 530                        NaN          Middle          Full-time employee
# 708                         18          Senior          Full-time employee
# 726                         10          Senior          Full-time employee
# 829                         11          Middle          Full-time employee
# 832                         12          Senior  Self-employed (freelancer)
# 848                          1          Junior          Full-time employee
# 904                         10          Senior          Full-time employee
# 961                          4            Head          Full-time employee
# 1039                        15          Middle          Full-time employee
# 1063                         5            Lead          Full-time employee
# 1148                        10          Senior          Full-time employee
# 1180                       NaN             NaN                         NaN
# 1181                       NaN             NaN                         NaN
# 1231                       NaN             NaN                         NaN
#
#              Company type
# 11                Product
# 12                    NaN
# 28                Product
# 55                    NaN
# 113               Product
# 300               Product
# 330               Product
# 340                   NaN
# 365               Startup
# 374               Product
# 418               Product
# 473                   NaN
# 529                   NaN
# 530               Product
# 708               Product
# 726               Product
# 829               Product
# 832   Consulting / Agency
# 848               Product
# 904                   NaN
# 961   Consulting / Agency
# 1039  Consulting / Agency
# 1063              Startup
# 1148              Product
# 1180                  NaN
# 1181                  NaN
# 1231                  NaN

# %%
df.dropna(subset=['Age'], inplace = True)
df.sample(3)
# Out:
#        Age  Gender    City           Position  Total years of experience  \
# 1203  33.0  Female  Munich   Software Engineer                        10
# 420   31.0  Female  Munich   Software Engineer                         2
# 62    34.0    Male  Munich  Frontend Developer                         5
#
#      Years of experience in Germany Seniority level  \
# 1203                              3          Senior
# 420                               2          Middle
# 62                                5          Senior
#
#      Your main technology / programming language  \
# 1203                                        Java
# 420                                         Java
# 62                                JavaScript/ES6
#
#      Other technologies/programming languages you use often  \
# 1203                                                SQL
# 420                                                 SQL
# 62                                                  NaN
#
#      Number of vacation days   Employment status   Сontract duration  \
# 1203                      25  Full-time employee  Unlimited contract
# 420                       28  Full-time employee  Unlimited contract
# 62                        27  Full-time employee  Unlimited contract
#
#      Main language at work Company size Company type  total salary
# 1203               English        11-50    Outsourse       47500.0
# 420                 German        1000+      Product       61000.0
# 62                 English        11-50      Product       73500.0

# %%
fig = px.box(df, y = 'total salary', title = 'Total salary + bonus + stock in EUR Box Plot')
fig.show()

# %%
out1 = df.loc[(df['total salary'] > 250000.00)]
out1
# Out:
#       Age  Gender       City                    Position   \
# 279  39.0    Male     Berlin              Product Manager
# 441  32.0    Male     Berlin                          CTO
# 494  39.0    Male     Berlin                      Manager
# 564  30.0    Male     Berlin                Data Engineer
# 574  38.0    Male     Berlin  Freelance AI lead / advisor
# 576  24.0    Male     Munich               Data Scientist
# 630  40.0    Male  Cupertino            Software Engineer
# 732  36.0    Male     Munich                       DevOps
# 745  35.0    Male     Berlin            Software Engineer
# 778  42.0    Male     Berlin           Frontend Developer
# 853  29.0  Female    Cologne                  ML Engineer
# 958  36.0    Male     Zurich            Backend Developer
# 966  35.0    Male     Berlin                Data Engineer
# 993  29.0    Male     London            Software Engineer
#
#     Total years of experience Years of experience in Germany Seniority level  \
# 279                        10                              5            Lead
# 441                        10                              4             CTO
# 494                        11                              9            Head
# 564                         5                              4            Lead
# 574                        20                              7            Head
# 576                         1                              1          Junior
# 630                        20                              0            Lead
# 732                        16                              0          Senior
# 745                        13                              5            Lead
# 778                        18                              5          Senior
# 853                         1                              1          Middle
# 958                        15                              2          Senior
# 966                         6                              6          Senior
# 993                         9                              0          Senior
#
#     Your main technology / programming language  \
# 279                                         NaN
# 441                                        JAVA
# 494                                     Python
# 564                                         NaN
# 574                                           C
# 576                                         C++
# 630                                       Swift
# 732                                         SRE
# 745                                  TypeScript
# 778                                    React JS
# 853                                       julia
# 958                                         C++
# 966                                        Java
# 993                                  Typescript
#
#     Other technologies/programming languages you use often  \
# 279                                                NaN
# 441                                      Python, C/C++
# 494                  Python, Kotlin, Java / Scala, AWS
# 564                                             Python
# 574                              Python, C/C++, Docker
# 576  Python, C/C++, Swift, Java / Scala, R, SQL, Go...
# 630                                                NaN
# 732                                  Python, C/C++, Go
# 745  Python, Javascript / Typescript, SQL, AWS, Goo...
# 778                            Javascript / Typescript
# 853                                                NaN
# 958                                C/C++, Java / Scala
# 966  Python, Java / Scala, SQL, Go, AWS, Kubernetes...
# 993              Javascript / Typescript, Java / Scala
#
#     Number of vacation days           Employment status   Сontract duration  \
# 279                      25          Full-time employee  Unlimited contract
# 441                      28          Full-time employee  Unlimited contract
# 494                      28          Full-time employee  Unlimited contract
# 564                      26          Full-time employee  Unlimited contract
# 574                       0  Self-employed (freelancer)                   0
# 576                     NaN          Full-time employee                 NaN
# 630                      45          Full-time employee  Unlimited contract
# 732                      30          Full-time employee  Unlimited contract
# 745                      29          Full-time employee  Unlimited contract
# 778                      35          Full-time employee  Unlimited contract
# 853                      99          Full-time employee  Unlimited contract
# 958                      25          Full-time employee  Unlimited contract
# 966                      14  Self-employed (freelancer)  Temporary contract
# 993                      25          Full-time employee  Unlimited contract
#
#     Main language at work Company size         Company type  total salary
# 279               English        1000+              Product  3.200000e+05
# 441               English     101-1000              Product  4.000000e+05
# 494               English        1000+              Product  3.300000e+05
# 564               English        1000+              Product  1.240000e+06
# 574               English     up to 10  Consulting / Agency  4.000000e+05
# 576               English     101-1000              Startup  3.000000e+05
# 630               English        1000+              Product  7.000000e+05
# 732               English        1000+              Product  2.550000e+05
# 745               English     101-1000              Startup  3.030000e+05
# 778               English     101-1000              Product  9.450000e+05
# 853               English     up to 10              Startup  5.500000e+09
# 958               English        1000+              Product  2.720000e+05
# 966               English        11-50              Startup  4.000000e+05
# 993               English        1000+         Corporation   2.830000e+05

# %%
to_drop1 = out1.index[:14].tolist()
df = df.drop(to_drop1)
df.sample(3)
# Out:
#       Age Gender     City            Position  Total years of experience  \
# 460  32.0   Male  Hamburg    Software Engineer                        12
# 112  33.0   Male   Berlin    Backend Developer                        12
# 199  32.0   Male   Munich  Fullstack Developer                         9
#
#     Years of experience in Germany Seniority level  \
# 460                              7          Senior
# 112                              6            Lead
# 199                              2          Senior
#
#     Your main technology / programming language  \
# 460                                        Java
# 112                                         PHP
# 199                                        Java
#
#     Other technologies/programming languages you use often  \
# 460  Kotlin, PHP, Javascript / Typescript, Java / S...
# 112          Javascript / Typescript, SQL, AWS, Docker
# 199  Javascript / Typescript, Kubernetes, Docker, A...
#
#     Number of vacation days   Employment status   Сontract duration  \
# 460                      28  Full-time employee  Unlimited contract
# 112                      27  Full-time employee  Unlimited contract
# 199                      26  Full-time employee  Unlimited contract
#
#     Main language at work Company size Company type  total salary
# 460                German     101-1000      Product       67300.0
# 112               English     101-1000      Product       65000.0
# 199               English        11-50      Product       74000.0

# %%
df['total salary'].describe()
# Out:
# count      1212.000000
# mean      81757.482327
# std       35807.218216
# min       10001.000000
# 25%       60000.000000
# 50%       73000.000000
# 75%       90000.000000
# max      240000.000000
# Name: total salary, dtype: float64

# %%
fig = px.box(df, y = 'total salary', title= 'Total salary + bonus + stock in EUR Box Plot')
fig.show()

# %%
df['Seniority level'].value_counts()
# Out:
# Senior                                       550
# Middle                                       358
# Lead                                         158
# Junior                                        77
# Head                                          41
# Principal                                      3
# intern                                         1
# student                                        1
# Intern                                         1
# Entry level                                    1
# Working Student                                1
# C-Level                                        1
# no idea, there are no ranges in the firm       1
# Student                                        1
# Key                                            1
# C-level executive manager                      1
# Director                                       1
# No level                                       1
# Work Center Manager                            1
# Manager                                        1
# VP                                             1
# No level                                       1
# Self employed                                  1
# Name: Seniority level, dtype: int64

# %%
df['Seniority level'].replace(np.nan, 'other', inplace = True)
df['Seniority level'] = replace_low_freq(df, 'Seniority level', 10, 'Other')
df['Seniority level'].value_counts()
# Out:
# Senior    550
# Middle    358
# Lead      158
# Junior     77
# Head       41
# Other      28
# Name: Seniority level, dtype: int64

# %%
commas(df, 'Total years of experience')
commas(df, 'Years of experience in Germany')
# Out:
# 1126     4.0
# 1218     8.0
# 627      4.0
# 1065     4.0
# 354     15.0
# Name: Total years of experience, dtype: float32
# 583    5.0
# 923    3.0
# 469    3.0
# 435    4.0
# 490    6.0
# Name: Years of experience in Germany, dtype: float32

# %%
df['Total years of experience'].replace('less than year', '0', inplace = True)
df['Total years of experience'].fillna(0, inplace = True)
df['Years of experience in Germany'].replace(np.nan, 0, inplace = True)
df.loc[df['Years of experience in Germany'] < 1.0, 'Years of experience in Germany'] = 0

# %%
df['Main language at work'].value_counts()
# Out:
# English               988
# German                181
# Russian                12
# Italian                 3
# Spanish                 3
# English and German      2
# Polish                  2
# Русский                 2
# Czech                   2
# 50/50                   1
# Deuglisch               1
# French                  1
# both                    1
# Russian, English        1
# Name: Main language at work, dtype: int64

# %%
df['Main language at work'].fillna('Unknown', inplace = True)
df['Main language at work'] = replace_low_freq(df, 'Main language at work', 10, 'Other')
df['Main language at work'].value_counts()
# Out:
# English    988
# German     181
# Other       19
# Unknown     12
# Russian     12
# Name: Main language at work, dtype: int64

# %%
df['Company type'] = replace_low_freq(df, 'Company type', 10, 'other')
df['Company type'].value_counts()
# Out:
# Product                739
# Startup                246
# Consulting / Agency    138
# other                   73
# Name: Company type, dtype: int64

# %%
df['City'] = replace_low_freq(df, 'City', 5, 'other')
df['City'].value_counts()
# Out:
# Berlin        656
# Munich        230
# other         161
# Frankfurt      42
# Hamburg        38
# Stuttgart      26
# Cologne        19
# Amsterdam       9
# Stuttgart       7
# Düsseldorf      6
# Moscow          6
# Karlsruhe       6
# Prague          6
# Name: City, dtype: int64

# %%
df.rename(columns = {'Position ' : 'Position'}, inplace = True)
df['Gender'].fillna('Other', inplace = True)
df['Position'].fillna('unknown', inplace = True)
df['Total years of experience'].fillna(0, inplace = True)
df['Company size'].fillna('Unknown', inplace = True)
df['Company type'].fillna('Unknown', inplace = True)

df['Your main technology / programming language'].fillna('Unknown', inplace = True)
df['Other technologies/programming languages you use often'].fillna('Unknown', inplace = True)

replace_low_freq(df, 'Company type', 10, 'other')
df.drop(columns = {'Number of vacation days', 'Employment status', 'Сontract duration'}, inplace = True)

# %%
df['Your main technology / programming language'].fillna('Unknown', inplace = True)
df['Your main technology / programming language'].value_counts()
# Out:
# Java                 179
# Python               161
# Unknown              117
# PHP                   54
# C++                   35
#                     ...
# SAP BW / ABAP          1
# Go, PHP, SQL           1
# Kotlin                 1
# Jira                   1
# consumer analysis      1
# Name: Your main technology / programming language, Length: 253, dtype: int64

# %%
df['Other technologies/programming languages you use often'].fillna('Unknown', inplace = True)
df['Other technologies/programming languages you use often'].value_counts()
# Out:
# Unknown                                                           146
# Javascript / Typescript                                            42
# Python                                                             36
# SQL                                                                31
# AWS, Docker                                                        15
#                                                                  ...
# Javascript / Typescript, Java / Scala, AWS, Kubernetes, Docker      1
# Kotlin, Java / Scala, SQL, Kubernetes, Docker                       1
# Python, C/C++, Javascript / Typescript, SQL, Docker                 1
# Google Cloud, Kubernetes, Docker, Shell                             1
# Python, AWS, Kubernetes, Docker, terraform, ansible                 1
# Name: Other technologies/programming languages you use often, Length: 552, dtype: int64

# %%
df['programming language'] = df['Your main technology / programming language'] + ',' + df['Other technologies/programming languages you use often']
df.drop(columns={'Your main technology / programming language', 'Other technologies/programming languages you use often'}, inplace = True)
df.sample(5)
# Out:
#        Age  Gender       City           Position  Total years of experience  \
# 1129  33.0    Male     Munich  Backend Developer                       13.0
# 224   35.0    Male     Berlin  Software Engineer                       15.0
# 816   33.0  Female     Berlin     Data Scientist                        8.0
# 490   29.0    Male     Munich  Software Engineer                        8.0
# 978   30.0    Male  Frankfurt     Data Scientist                        5.0
#
#       Years of experience in Germany Seniority level Main language at work  \
# 1129                             3.0          Senior               English
# 224                              4.0          Senior               English
# 816                              4.0          Senior               English
# 490                              6.0          Middle               English
# 978                              4.0          Middle               English
#
#      Company size Company type  total salary  \
# 1129       51-100      Product       77000.0
# 224        51-100      Startup       70000.0
# 816         1000+      Product       77000.0
# 490         1000+      Product       75000.0
# 978         11-50      Startup       52500.0
#
#                                    programming language
# 1129          Java,Python, Javascript / Typescript, AWS
# 224   go,PHP, Javascript / Typescript, Perl, AWS, Ku...
# 816                   Python ,SQL, Google Cloud, Docker
# 490                    PHP,Javascript / Typescript, SQL
# 978   Python,Javascript / Typescript, Java / Scala, ...

# %%
missing_values()
# Out:
# missing values in column 'Age': 0
# missing values in column 'Gender': 0
# missing values in column 'City': 0
# missing values in column 'Position': 0
# missing values in column 'Total years of experience': 0
# missing values in column 'Years of experience in Germany': 0
# missing values in column 'Seniority level': 0
# missing values in column 'Main language at work': 0
# missing values in column 'Company size': 0
# missing values in column 'Company type': 0
# missing values in column 'total salary': 0
# missing values in column 'programming language': 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1212 entries, 0 to 1252
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             1212 non-null   float64
#  1   Gender                          1212 non-null   object
#  2   City                            1212 non-null   object
#  3   Position                        1212 non-null   object
#  4   Total years of experience       1212 non-null   float32
#  5   Years of experience in Germany  1212 non-null   float32
#  6   Seniority level                 1212 non-null   object
#  7   Main language at work           1212 non-null   object
#  8   Company size                    1212 non-null   object
#  9   Company type                    1212 non-null   object
#  10  total salary                    1212 non-null   float64
#  11  programming language            1212 non-null   object
# dtypes: float32(2), float64(2), object(8)
# memory usage: 113.6+ KB

# %%
df['Total years of experience'] = df['Total years of experience'].apply(lambda x: np.float64(x))
df['Years of experience in Germany'] = df['Years of experience in Germany'].apply(lambda x: np.float64(x))

#df[['Gender', 'City', 'Position', 'Seniority level', 'Main language at work', 'Company size',
#       'Company type', 'programming language']] = df[['Gender', 'City', 'Position', 'Seniority level',
#                                                      'Main language at work', 'Company size', 'Company type', 'programming language']].astype('category')

# %%
df.select_dtypes(include = np.number).columns
# Out:
# Index(['Age', 'Total years of experience', 'Years of experience in Germany',
#        'total salary'],
#       dtype='object')

# %%
df.select_dtypes(exclude = np.number).columns
# Out:
# Index(['Gender', 'City', 'Position', 'Seniority level',
#        'Main language at work', 'Company size', 'Company type',
#        'programming language'],
#       dtype='object')

# %% [markdown]
# 1. built numeric_features, categorical_features, numeric_transformer, categorical_transformer to pipeline.
#
# 2. since cleaned all the missing and null values, the scaler can chosen StandardScaler.
#
# 3. for categorical data, this data set used ExtraTreeRegressor and RandomForestRegressor.
#
# 4. defined data set for training and testing data sets.

# %%
numeric_features = ['Age', 'Total years of experience', 'Years of experience in Germany',
       'total salary']
numeric_transformer = Pipeline( steps = [
        ("imputer", SimpleImputer()),
        ("scaler", StandardScaler())])

categorical_features = ['Gender', 'City', 'Position', 'Seniority level',
                         'Main language at work', 'Company size', 'Company type']
categorical_transformer = Pipeline( steps = [
        ("imputer", SimpleImputer(strategy = 'most_frequent')),
        ("encode", OneHotEncoder())])


preprocessor = ColumnTransformer(transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
dfm = df
dfm = pd.get_dummies(dfm, drop_first = True)
y = np.array(dfm['total salary']).reshape(-1,1)
x = np.array(dfm.drop(columns = {'total salary'}))
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

# %% [markdown]
# <b> Pipeline 1 WITHOUT feature selection

# %%
#Build pipeline
pipe1 = [('pre', preprocessor), ('reg', ExtraTreeRegressor(random_state= 0))]
pipeline1 = Pipeline(pipe1)
pipeline1 = Pipeline([('clf', ExtraTreeRegressor())])


pipeline1.fit(x_train, y_train)
y_pred1 = pipeline1.predict(x_test)
cv1 = cross_val_score(ExtraTreeRegressor(), x, y, cv = 5)

print('Training set accuracy: {:.2f}'.format(pipeline1.score(x_train, y_train)))
print('Testing set accuracy: {:.2f}'.format(pipeline1.score(x_test, y_test)))
print('RMSE: {:.2f}'.format(np.sqrt(mean_squared_error(y_test, y_pred1))))
print('R2: {:.2f}'.format(r2_score(y_test, y_pred1)))
print('Cross Validation score: {:.2f}'.format(cv1.mean()))
# Out:
# Training set accuracy: 1.00
# Testing set accuracy: -0.04
# RMSE: 37274.91
# R2: -0.04
# Cross Validation score: -0.03

# %% [markdown]
# <b> Pipeline 2 WITHOUT feature selection

# %%
dfm = pd.get_dummies(dfm, drop_first = True)
y = np.array(dfm['total salary']).reshape(-1)
x = np.array(dfm.drop(columns = {'total salary'}))
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

# Create the pipeline
pipe2 = Pipeline([('pre', preprocessor), ('reg', RandomForestRegressor(n_estimators = 10, random_state = 0))])
pipeline2 = make_pipeline(StandardScaler(), RandomForestRegressor(n_estimators = 5, random_state=0))


# Fit the pipeline to the training data
pipeline2.fit(x_train, y_train)
y_pred2 = pipeline2.predict(x_test)
cv2 = cross_val_score(RandomForestRegressor(), x, y, cv = 5)


# Evaluate the pipeline on the test data
print('Training set accuracy: {:.2f}'.format(pipeline2.score(x_train, y_train)))
print('Testing set accuracy: {:.2f}'.format(pipeline2.score(x_test, y_test)))
print('RMSE: {:.2f}'.format(np.sqrt(mean_squared_error(y_test, y_pred2))))
print('R2: {:.2f}'.format(r2_score(y_test, y_pred2)))
print('Cross Validation score: {:.2f}'.format(cv2.mean()))
# Out:
# Training set accuracy: 0.81
# Testing set accuracy: 0.12
# RMSE: 34257.57
# R2: 0.12
# Cross Validation score: 0.16

# %% [markdown]
# <b> Feature selection with VarianceThreshold

# %%
var_th = VarianceThreshold(.2)
y = dfm['total salary']
x = dfm.drop('total salary', axis = 1)

post_vt = var_th.fit_transform(x)
print(x.shape)
print(post_vt.shape)

mask = var_th.get_support()
new_features = x.columns[mask]
print(new_features)
# Out:
# (1212, 1118)
# (1212, 9)
# Index(['Age', 'Total years of experience', 'Years of experience in Germany',
#        'City_Berlin', 'Position_Software Engineer', 'Seniority level_Middle',
#        'Seniority level_Senior', 'Company size_101-1000',
#        'Company type_Product'],
#       dtype='object')

# %% [markdown]
# <b> Feature selection with mutual_info_regression

# %%
y = dfm['total salary']
x = dfm.drop('total salary', axis = 1)
mi = mutual_info_regression(x, y)

mi_scores = list(zip(x.columns, mi))
mi_scores = sorted(mi_scores, key=lambda x: x[1], reverse=True)


# print the mi_scores list
print('Mutual information scores:')
for i, s in mi_scores:
    print('{} : {:.2f}'.format(i, s))
# Out:
# Mutual information scores:
# Total years of experience : 0.18
# Years of experience in Germany : 0.12
# Seniority level_Middle : 0.12
# Seniority level_Senior : 0.08
# Age : 0.08
# City_other : 0.06
# programming language_JS,Javascript / Typescript, Google Cloud, Kubernetes, Docker : 0.06
# programming language_Python,R, SQL, AWS, Azure, Docker : 0.05
# programming language_Java,Kotlin, SQL, Kubernetes, Docker : 0.04
# programming language_C#,Javascript / Typescript, .NET, Azure, Docker : 0.04
# programming language_Java,Python, Javascript / Typescript, SQL, AWS, Kubernetes : 0.04
# programming language_Python ,Python, Docker : 0.04
# Position_Head of IT  : 0.03
# Position_unknown : 0.03
# Position_Backend Developer : 0.03
# programming language_PHP,PHP, Javascript / Typescript, Java / Scala : 0.03
# programming language_Java,Java / Scala, AWS, Azure, Kubernetes, Docker : 0.03
# programming language_Kubernetes,Python, AWS, Google Cloud, Kubernetes, Docker : 0.03
# Position_Frontend Developer : 0.03
# programming language_Scala,Python, Kotlin, Java / Scala, SQL, AWS, Kubernetes, Docker : 0.03
# programming language_js,Javascript / Typescript : 0.03
# Seniority level_Junior : 0.03
# programming language_Java,Javascript / Typescript, .NET, Java / Scala, Docker : 0.03
# programming language_Java,Javascript / Typescript, Go : 0.03
# programming language_Java,R, SQL, Perl, Docker : 0.03
# programming language_TypeScript,Kotlin, Javascript / Typescript : 0.03
# programming language_ML,Python, Java / Scala, R, SQL, AWS, Azure : 0.03
# programming language_Python,Python, SQL, AWS, Azure, Kubernetes, Docker : 0.03
# programming language_Python,AWS, Docker : 0.03
# Seniority level_Lead : 0.03
# City_Munich : 0.03
# programming language_C#,SQL, Azure : 0.03
# programming language_Ruby on Rails,Ruby, Kubernetes, Docker : 0.03
# programming language_Python,Python : 0.03
# programming language_C++,SQL : 0.03
# programming language_R,Python, R, Azure : 0.03
# programming language_Python,Python, Go, AWS, Kubernetes, Docker : 0.03
# programming language_python,Javascript / Typescript, SQL, AWS, Docker : 0.03
# programming language_Cloud,Kotlin, Java / Scala, AWS, Kubernetes, Docker : 0.03
# Position_QA Engineer : 0.03
# programming language_go,SQL, Go, AWS, Kubernetes, Docker : 0.03
# programming language_Java,SQL, AWS, Kubernetes, Docker, Groovy : 0.03
# programming language_Python,Python, Ruby, Java / Scala, Go, Rust, AWS, Kubernetes, Docker, Terraform, helm, packer : 0.03
# programming language_Java,Python, SQL, AWS, Docker : 0.03
# Company type_Product : 0.03
# programming language_T-SQL,Unknown : 0.03
# programming language_Unknown,Python, Java / Scala, AWS, Kubernetes, Docker : 0.03
# programming language_PHP,PHP, Javascript / Typescript, SQL, Docker : 0.03
# programming language_PHP,PHP, SQL, Kubernetes, Docker : 0.03
# programming language_Java,Python, Kotlin, Javascript / Typescript, SQL, Docker : 0.03
# programming language_Kubernetes,Go, Kubernetes : 0.02
# programming language_TypeScript,Javascript / Typescript, Azure : 0.02
# programming language_Java,Java / Scala, SQL, Kubernetes, Docker : 0.02
# programming language_JavaScript,Javascript / Typescript, AWS, Docker : 0.02
# programming language_kotlin,Python, Kotlin, Javascript / Typescript, Java / Scala, SQL, AWS, Kubernetes, Docker : 0.02
# programming language_Python,SQL, AWS, Kubernetes, Docker : 0.02
# programming language_Python ,Python, SQL, Google Cloud : 0.02
# Gender_Male : 0.02
# City_Stuttgart : 0.02
# programming language_Java,Javascript / Typescript, .NET : 0.02
# programming language_Python,Python, SQL, Google Cloud : 0.02
# programming language_C++, Java, Embedded C,Python, C/C++, .NET, Java / Scala : 0.02
# Main language at work_Other : 0.02
# programming language_Spark,Python, Java / Scala, R, SQL : 0.02
# Position_Account Managet : 0.02
# Position_Product Analyst : 0.02
# programming language_PHP,PHP, Javascript / Typescript, SQL : 0.02
# programming language_Python,R, SQL, AWS, Kubernetes, Docker : 0.02
# programming language_Network,Unknown : 0.02
# programming language_Python,Javascript / Typescript : 0.02
# City_Stuttgart  : 0.02
# programming language_PHP,SQL, Kubernetes, Docker : 0.02
# programming language_PHP,Javascript / Typescript, SQL, Go, Docker : 0.02
# Position_Big Data Engineer : 0.02
# programming language_Java, Kotlin,Kotlin, Java / Scala, AWS : 0.02
# programming language_Php,PHP, Javascript / Typescript, SQL : 0.02
# programming language_Scala,Java / Scala, AWS, Kubernetes, Docker : 0.02
# programming language_python,Python, SQL, Go, AWS, Google Cloud, Azure, Kubernetes, Docker : 0.02
# programming language_Java,Kotlin, Java / Scala, AWS : 0.02
# programming language_Frontend,C/C++, Javascript / Typescript, Go, AWS, Docker : 0.02
# programming language_python,Python, Azure, Kubernetes : 0.02
# programming language_Go,Go, Google Cloud, Kubernetes, Docker : 0.02
# programming language_c++,Python, C/C++, Javascript / Typescript, Java / Scala, AWS, Kubernetes, Docker : 0.02
# programming language_PHP,PHP, AWS, Google Cloud : 0.02
# programming language_C,Python, C/C++ : 0.02
# programming language_PHP,PHP, Javascript / Typescript, SQL, AWS, Docker : 0.02
# Position_Team lead : 0.02
# Position_Data Analyst : 0.02
# programming language_JavaScript,Python, Javascript / Typescript : 0.02
# programming language_Java,Kotlin, Javascript / Typescript, Java / Scala, Kubernetes, Docker : 0.02
# programming language_python,Python, Javascript / Typescript : 0.02
# programming language_Python,C/C++, SQL, AWS, Kubernetes, Docker : 0.02
# programming language_Ruby,SQL, Elixir : 0.02
# programming language_PHP,Kotlin, SQL, Kubernetes, Docker : 0.02
# programming language_Ruby,Python, Javascript / Typescript, Ruby, .NET, Java / Scala, Azure, Kubernetes : 0.02
# programming language_TypeScript, React,Javascript / Typescript, Google Cloud, Kubernetes, Docker : 0.02
# programming language_Elixir,Unknown : 0.02
# programming language_Typescript,PHP, Javascript / Typescript, AWS : 0.02
# programming language_Java,Python, Kotlin, Go, Kubernetes : 0.02
# programming language_Python,Python, C/C++ : 0.02
# programming language_Python,Java / Scala, SQL, AWS, Google Cloud : 0.02
# Position_VP Engineering : 0.02
# Position_iOS Developer : 0.02
# Company size_Unknown : 0.02
# programming language_C#,Javascript / Typescript, .NET, SQL, Kubernetes : 0.02
# programming language_k8s,Python, Google Cloud, Kubernetes, Docker : 0.02
# City_Moscow : 0.02
# programming language_Python,Python, SQL, Docker : 0.02
# programming language_PowerShell,SQL : 0.02
# Position_Researcher/ Consumer Insights Analyst  : 0.02
# programming language_C++,Java / Scala : 0.02
# programming language_javascript,Javascript / Typescript, Kubernetes, Docker : 0.02
# programming language_JavaScript ,PHP : 0.02
# Position_QA Manager  : 0.02
# Position_Data Engineer : 0.02
# programming language_JavaScript/ES6,Unknown : 0.02
# programming language_Python,Unknown : 0.02
# programming language_Sql, BQ, tableau, gtm, ga,Python, Javascript / Typescript, SQL : 0.02
# programming language_Unknown,.NET, Azure : 0.02
# programming language_PHP,PHP : 0.02
# programming language_PHP,SQL, Google Cloud, Kubernetes, Docker : 0.02
# programming language_Angular, React,Python, Javascript / Typescript, Docker : 0.02
# programming language_Python,Python, SQL, AWS, Google Cloud, Kubernetes, Docker : 0.02
# programming language_Typescript ,Javascript / Typescript, Java / Scala, Go, Rust, AWS, Kubernetes, Docker : 0.02
# programming language_Go/Python,AWS, Kubernetes, Docker : 0.02
# programming language_C++,Javascript / Typescript, Go : 0.02
# programming language_Node.js,Swift, Javascript / Typescript, Go, AWS, Kubernetes, Docker : 0.02
# programming language_C++,Python : 0.02
# programming language_.NET,.NET, SQL : 0.02
# programming language_JavaScript/Typescript,Javascript / Typescript : 0.02
# programming language_Python,.NET : 0.02
# programming language_C#,.NET : 0.02
# programming language_Java,Kotlin, Javascript / Typescript, Java / Scala, AWS, Azure, Kubernetes, Docker : 0.02
# programming language_javascript,Google Cloud, Docker : 0.02
# programming language_C, C++,C/C++, Linux Kernel : 0.02
# programming language_Java,Python, Kotlin, Javascript / Typescript, Go, AWS, Kubernetes, Docker : 0.02
# programming language_Angular, Typescript,PHP, Javascript / Typescript : 0.02
# programming language_Swift,Javascript / Typescript : 0.02
# programming language_python,Python, Javascript / Typescript, SQL, AWS, Docker : 0.02
# programming language_C#,Javascript / Typescript, .NET, Kubernetes, Docker : 0.02
# programming language_Java,Python, Kubernetes : 0.02
# programming language_Swift,Kotlin, Javascript / Typescript, AWS : 0.02
# Position_Data architect : 0.02
# programming language_C,C/C++ : 0.02
# programming language_Javascript,Python, Javascript / Typescript : 0.02
# programming language_Javascript/Typescript,AWS : 0.02
# programming language_.NET,Javascript / Typescript, .NET, Docker : 0.02
# Position_XR Developer : 0.02
# Position_DBA : 0.02
# programming language_iOS,Kotlin, C/C++, Swift, Ruby : 0.02
# programming language_Elixir,Javascript / Typescript, Ruby, SQL, Google Cloud, Kubernetes, Docker : 0.02
# programming language_Javascript / Typescript,NodeJS : 0.02
# programming language_SAP,Unknown : 0.02
# programming language_Java/Groovy,AWS, Docker : 0.02
# programming language_ABAP,PHP, SQL, SAP / ABAP, Delphi : 0.02
# programming language_Kuberenetes, Openstack,Python, Go, Kubernetes, Docker, Openstack : 0.02
# programming language_Java / Scala,Kotlin, Java / Scala, Clojure, Rust, AWS, Kubernetes, Docker : 0.02
# programming language_Java,Javascript / Typescript, Java / Scala, Google Cloud, Docker : 0.02
# Position_Program Manager : 0.02
# programming language_Unknown,Python, SQL, Azure : 0.01
# programming language_.net,Javascript / Typescript, Java / Scala, Go : 0.01
# programming language_Java,Java / Scala, Google Cloud, Kubernetes, Docker : 0.01
# programming language_JavaScript,Javascript / Typescript, Ruby, Kubernetes, Docker : 0.01
# programming language_Java,Java / Scala, SQL, Go, Google Cloud, Kubernetes, Docker : 0.01
# programming language_Kotlin,Kotlin, Java / Scala, AWS, Kubernetes, Docker : 0.01
# programming language_SWIFT,Swift, Javascript / Typescript, Java / Scala, Google Cloud : 0.01
# programming language_Kotlin/PHP,Kotlin, PHP, SQL : 0.01
# programming language_Python,Python, Azure : 0.01
# programming language_Java,Python, R, SQL, Kubernetes, Docker : 0.01
# programming language_Kotlin,Kotlin, .NET, SQL, AWS : 0.01
# programming language_Javascript, Angular,Javascript / Typescript : 0.01
# Position_Director of Engineering : 0.01
# programming language_SAP BW / ABAP,SAP / ABAP : 0.01
# programming language_Php,PHP, Javascript / Typescript, SQL, Docker : 0.01
# Position_BI Consultant SAP/ Data Engineer : 0.01
# programming language_Javascript,PHP, SQL : 0.01
# programming language_Swift,Swift, Objective-C : 0.01
# programming language_Python,Python, AWS, Docker : 0.01
# programming language_iOS,Swift, objective-c : 0.01
# Position_Team Manager : 0.01
# programming language_kotlin,Kotlin, Javascript / Typescript, AWS, Google Cloud, Kubernetes, Docker : 0.01
# Position_Analyst : 0.01
# programming language_JavaScript,Javascript / Typescript, Google Cloud : 0.01
# programming language_python,C/C++, R, SQL : 0.01
# programming language_BI, DWH, ETL/ELT,Python, SQL, MS SQL Stack, Oracle, Informatica PowerCenter : 0.01
# Main language at work_Russian : 0.01
# programming language_TypeScript,Javascript / Typescript : 0.01
# programming language_C, C++,Python : 0.01
# programming language_Kotlin,Javascript / Typescript, Java / Scala, Flutter : 0.01
# Company type_Startup : 0.01
# Position_Data Science Manager : 0.01
# programming language_C,Python, C/C++, Javascript / Typescript, Java / Scala, Perl, MATLAB : 0.01
# programming language_Python,Python, C/C++, Javascript / Typescript, Java / Scala, SQL, Kubernetes, Docker : 0.01
# programming language_.Net,Python : 0.01
# programming language_Java,Kotlin, Java / Scala, Google Cloud, Kubernetes, Docker : 0.01
# programming language_Android/Kotlin,Kotlin, Java / Scala : 0.01
# programming language_Kotlin,Kotlin, Java / Scala : 0.01
# City_Prague : 0.01
# programming language_Java/Kotlin,Kotlin, C/C++, Java / Scala : 0.01
# Position_Software Sales : 0.01
# programming language_Java,Kotlin, Javascript / Typescript, Java / Scala, AWS, Kubernetes, Docker : 0.01
# programming language_Unknown,Adobe Cloud, Sketch, 3Ds Max : 0.01
# programming language_Python,Python, C/C++, AWS, Kubernetes, Docker : 0.01
# programming language_PHP,Python, Javascript / Typescript, SQL, AWS, Docker : 0.01
# programming language_C++,Python, Javascript / Typescript, Java / Scala, R, SQL, AWS, Google Cloud, Azure, Kubernetes, Docker : 0.01
# programming language_spark,Python, SQL, AWS : 0.01
# programming language_Python,Python, Javascript / Typescript, SQL, AWS : 0.01
# programming language_AWS,Python, AWS, Kubernetes, Docker : 0.01
# Position_Embedded Software Engineer : 0.01
# programming language_Java,SQL, AWS, Kubernetes, Docker : 0.01
# programming language_Web,Unknown : 0.01
# programming language_Unknown,Python, Java / Scala : 0.01
# programming language_Java,AWS, Docker : 0.01
# City_Cologne : 0.01
# programming language_Golang,Python, Javascript / Typescript, SQL, Go, Perl, Google Cloud, Kubernetes, Docker : 0.01
# programming language_Jira,Unknown : 0.01
# programming language_C++/C#,C/C++, .NET, SQL : 0.01
# programming language_Unknown,Python, SQL : 0.01
# programming language_SAP / ABAP,SQL, SAP / ABAP : 0.01
# programming language_Java,Unknown : 0.01
# programming language_Java,C/C++ : 0.01
# programming language_python,AWS, Terraform, Scala Spark,  : 0.01
# programming language_Python,Python, Java / Scala : 0.01
# programming language_SQL,Python, AWS, Google Cloud, Azure, Alteryx, SAS : 0.01
# Position_Consultant : 0.01
# programming language_R,R, SQL : 0.01
# programming language_Cloud,Unknown : 0.01
# programming language_Clojure,Swift, Javascript / Typescript, Java / Scala, Clojure : 0.01
# programming language_Javascript / Typescript,Javascript / Typescript, Docker : 0.01
# programming language_Swift,Kotlin, Javascript / Typescript : 0.01
# Company size_51-100 : 0.01
# Position_Engineering Manager : 0.01
# programming language_Python,PHP, Javascript / Typescript, SQL, Go, Google Cloud, Kubernetes, Docker : 0.01
# programming language_C#,Javascript / Typescript, .NET, SQL, Azure, Kubernetes, Docker : 0.01
# Position_C/C++/Java developer : 0.01
# programming language_Js,Javascript / Typescript, SQL, AWS, Google Cloud, Kubernetes, Docker, Quorum : 0.01
# programming language_Swift,Swift, Java / Scala : 0.01
# programming language_C#,Python, .NET, Azure, Kubernetes, Docker : 0.01
# programming language_Java,C/C++, .NET, Java / Scala, AWS, Kubernetes, Docker : 0.01
# programming language_Python,Python, Javascript / Typescript, SQL, AWS, Kubernetes, Docker : 0.01
# programming language_Elixir,SQL : 0.01
# programming language_Scala,Java / Scala, SQL, Go, Google Cloud, Kubernetes, Docker : 0.01
# programming language_Scala,Python, Javascript / Typescript, Java / Scala, AWS : 0.01
# programming language_python,Python, Javascript / Typescript, AWS, Docker : 0.01
# programming language_Java,Kotlin, Google Cloud : 0.01
# Position_Head of IT : 0.01
# programming language_NodeJS, Typescript, AWS,Javascript / Typescript, Java / Scala, AWS : 0.01
# programming language_PHP,Javascript / Typescript, SQL : 0.01
# programming language_JavaScript / TypeScript,Javascript / Typescript : 0.01
# programming language_Javascript,Javascript / Typescript, AWS, Azure, Docker : 0.01
# Company size_101-1000 : 0.01
# programming language_Qml,C/C++ : 0.01
# programming language_Swift,Kotlin, .NET, Java / Scala, Dart : 0.01
# programming language_Python,Java / Scala, SQL, AWS, Google Cloud, Azure, Docker : 0.01
# programming language_Apotheker,Unknown : 0.01
# programming language_Swift,Ruby, Objective C : 0.01
# programming language_Java,Google Cloud, Kubernetes, Docker : 0.01
# programming language_Javascript / Typescript,Unknown : 0.01
# programming language_golang,Go, Google Cloud, Kubernetes, Docker : 0.01
# programming language_Javascript,Python, Javascript / Typescript, SQL, AWS, Docker : 0.01
# programming language_FBD,PHP, Javascript / Typescript, SQL : 0.01
# programming language_Scala, React.js,Javascript / Typescript, SQL, AWS, Kubernetes, Docker : 0.01
# programming language_Php,Javascript / Typescript, AWS, Kubernetes, Docker : 0.01
# programming language_Unknown,Kubernetes, Docker : 0.01
# programming language_Python ,Python, Kubernetes, Docker, Ansible : 0.01
# programming language_Scala,Java / Scala : 0.01
# programming language_C++,Python, Swift, Java / Scala : 0.01
# programming language_Python,Kotlin, SQL, AWS, Docker, Spark : 0.01
# programming language_PHP,Python, PHP, Javascript / Typescript, SQL : 0.01
# programming language_PHP,PHP, Javascript / Typescript, SQL, Go, AWS : 0.01
# programming language_Unknown,Unknown : 0.01
# programming language_PHP,PHP, SQL, AWS, Kubernetes, Docker : 0.01
# programming language_JavaScript,Javascript / Typescript, Docker, HTML, CSS; Adobe XD : 0.01
# programming language_Java,PHP, Java / Scala : 0.01
# programming language_TypeScript,AWS, Kubernetes : 0.01
# programming language_iOS,Swift : 0.01
# programming language_PHP,PHP, Javascript / Typescript, Java / Scala, SQL, AWS, Docker : 0.01
# Position_Tech Lead : 0.01
# programming language_Java,Javascript / Typescript, Kubernetes, Docker, Angular : 0.01
# Position_Researcher : 0.01
# programming language_C#,Unknown : 0.01
# programming language_Python,Python, SQL, Google Cloud, Docker : 0.01
# programming language_Ruby,Ruby, Java / Scala, AWS, Kubernetes, Docker : 0.01
# programming language_Kotlin,Python, Kotlin, Java / Scala, SQL, AWS, Kubernetes, Docker : 0.01
# programming language_Java,Kotlin, AWS, Kubernetes, Docker : 0.01
# programming language_consumer analysis,Unknown : 0.01
# programming language_Python,AWS : 0.01
# programming language_Ruby,Ruby, Java / Scala, Go, AWS, Kubernetes, Docker : 0.01
# programming language_Java,SQL, Go, Kubernetes, Docker : 0.01
# programming language_Atlassian JIRA,SQL, Perl : 0.01
# programming language_Python,C/C++, AWS, Google Cloud, Docker : 0.01
# programming language_Ruby,Unknown : 0.01
# Position_Localization producer : 0.01
# Position_Tech recruiting : 0.01
# Position_Architect : 0.01
# programming language_SQL,Python, AWS, Kubernetes, Docker : 0.01
# programming language_Kotlin,Python, Kotlin, Java / Scala, Google Cloud, Kubernetes, Docker : 0.01
# programming language_Unknown,Python, SQL, AWS, Docker : 0.01
# programming language_C,Python, Javascript / Typescript, SQL, Docker : 0.01
# programming language_javascript,Javascript / Typescript, AWS, Docker : 0.01
# programming language_python,Kubernetes : 0.01
# programming language_PHP,Unknown : 0.01
# programming language_C#,.NET, SQL, Google Cloud, Kubernetes, Docker : 0.01
# programming language_Python,Python, Squish : 0.01
# programming language_Network Automation,Python : 0.01
# programming language_Java,Python, SQL, Kubernetes, Docker : 0.01
# programming language_Java,Kotlin, Java / Scala, Go, AWS, Kubernetes, Docker : 0.01
# Position_DatabEngineer : 0.01
# programming language_VHDL,Python : 0.01
# Position_IT Spezialist : 0.01
# programming language_TypeScript,Python, Javascript / Typescript, AWS, Docker : 0.01
# programming language_Python, Whole Apache Data Science Stack, AWS,Javascript / Typescript, SQL, AWS, Docker : 0.01
# programming language_Javascript,Javascript / Typescript, AWS, Docker : 0.01
# programming language_javascript,Javascript / Typescript : 0.01
# programming language_JavaScript ,AWS, Docker : 0.01
# programming language_Java,Java / Scala, Kubernetes, Docker : 0.01
# programming language_JavaScript/Typescript,PHP, SQL : 0.01
# Position_System Administrator : 0.01
# programming language_Python, statistics, SQL,Python, SQL, Google Cloud, Docker : 0.01
# programming language_python, scala,Python, Java / Scala, SQL, AWS, Docker : 0.01
# Position_Cloud Engineer : 0.01
# programming language_Ruby,Javascript / Typescript, Go, AWS, Docker : 0.01
# programming language_Java,Kotlin : 0.01
# programming language_Elixir,Erlang : 0.01
# programming language_Python,Javascript / Typescript, Java / Scala, R, Google Cloud, Azure, Kubernetes, Docker : 0.01
# programming language_Go,Google Cloud, Kubernetes, Docker, Shell : 0.01
# programming language_Unknown,Python, SQL, AWS, Azure : 0.01
# programming language_.NET,.NET, SQL, Azure, Docker : 0.01
# programming language_Java,Python, Javascript / Typescript : 0.01
# programming language_PHP,Javascript / Typescript, SQL, AWS, Kubernetes, Docker : 0.01
# programming language_Java Backend,Java / Scala, SQL, Docker : 0.01
# programming language_Python ,Kubernetes, Docker : 0.01
# programming language_C++,C/C++ : 0.01
# programming language_Unknown,SQL : 0.01
# programming language_Unknown,PHP, Javascript / Typescript, .NET, SQL, Google Cloud, Kubernetes, Docker : 0.01
# programming language_Scala,Java / Scala, SQL : 0.01
# programming language_Java,Kotlin, Java / Scala, SQL, AWS, Kubernetes, Docker : 0.01
# programming language_java,Python, Kotlin, Javascript / Typescript, Java / Scala, Docker : 0.01
# Position_Software Architekt : 0.01
# programming language_Js, TypeScript, Angular,Unknown : 0.01
# programming language_JavaScript,Javascript / Typescript, SQL, AWS : 0.01
# programming language_python,Python, SQL, Google Cloud, Kubernetes, Docker : 0.01
# programming language_JavaScript,Docker : 0.01
# programming language_Kotlin, Java,Kotlin, Java / Scala : 0.01
# programming language_C#, .net core,Python, .NET, AWS, Azure, Kubernetes, Docker : 0.01
# programming language_Unknown,Google Cloud, Kubernetes, Docker, Terraform, Bash : 0.01
# programming language_Java,Pl/sql : 0.01
# programming language_Java,Javascript / Typescript, Java / Scala, AWS, Azure, Kubernetes, Docker : 0.01
# programming language_Blockchain,Python, Kotlin, Java / Scala, SQL, Go, AWS, Google Cloud, Kubernetes, Docker : 0.01
# programming language_c#,.NET : 0.01
# Position_Dana Analyst : 0.01
# programming language_Java,Kotlin, PHP, Javascript / Typescript, Java / Scala : 0.01
# Position_Tech Leader : 0.01
# programming language_Ruby,Python, SQL, Go, AWS, Kubernetes, Docker : 0.01
# programming language_Python,Javascript / Typescript, Java / Scala, SQL : 0.01
# programming language_Agile,C/C++, PHP, .NET, SQL : 0.01
# programming language_Sql,Python, R, SQL : 0.01
# programming language_Go,Python, C/C++, Javascript / Typescript, Go : 0.01
# programming language_Python,Python, Javascript / Typescript, R : 0.01
# Position_Project manager : 0.01
# programming language_Java,Kotlin, Java / Scala, SQL, AWS, Google Cloud, Docker : 0.01
# programming language_C# .NET,.NET, SQL, AWS, Docker : 0.01
# programming language_Python ,SQL, AWS : 0.01
# programming language_Unknown,C/C++ : 0.01
# programming language_networking, linux, automation, cloud,Python, AWS : 0.01
# Seniority level_Other : 0.01
# programming language_Scala,Javascript / Typescript, Java / Scala, SQL, Go, AWS, Docker : 0.01
# programming language_JS,Python : 0.01
# programming language_DevOps,Python, AWS, Azure, Kubernetes, Docker : 0.01
# programming language_python,Python, Javascript / Typescript, SQL, Google Cloud, Docker : 0.01
# programming language_Java,Kotlin, SQL, Azure, Kubernetes, Docker, Mongo : 0.01
# programming language_php,PHP, Javascript / Typescript : 0.01
# programming language_Java,Java / Scala, SQL, AWS, Kubernetes, Docker : 0.01
# programming language_Swift, Objective-C,Ruby : 0.01
# programming language_Java,AWS, Kubernetes, Docker : 0.01
# programming language_JavaScript,Javascript / Typescript, SQL, AWS, Docker : 0.01
# programming language_JS,Python, Javascript / Typescript, AWS, Docker : 0.01
# programming language_Python,Python, SQL, AWS : 0.01
# programming language_none,Unknown : 0.01
# Position_DevOps Manager : 0.01
# programming language_Java,Ruby, Go, Perl : 0.01
# Gender_Other : 0.01
# programming language_Java,PHP, Javascript / Typescript, SQL : 0.01
# programming language_Terraform, Kubernetes, AWS, GCP, Ansible, Puppet,Ruby, Java / Scala, SQL, Go, AWS, Google Cloud, Kubernetes, Docker : 0.01
# programming language_Ruby,Go, Kubernetes, Docker : 0.01
# programming language_Java,Python, AWS, Kubernetes, Docker : 0.01
# programming language_PHP,SQL, Go, AWS, Docker : 0.01
# Position_Agile Coach : 0.01
# programming language_Embedded C++,Python, C/C++ : 0.01
# programming language_JavaScript, TypeScript,PHP : 0.01
# programming language_Golang,Python, Javascript / Typescript, SQL, AWS, Kubernetes, Docker : 0.01
# Gender_Female : 0.01
# programming language_java,Java / Scala, SQL : 0.01
# programming language_Java,Java / Scala, SQL, Docker : 0.01
# programming language_React / JavaScript,Javascript / Typescript : 0.01
# programming language_Python,Python, SQL, AWS, Google Cloud, Docker : 0.01
# programming language_Java,Kotlin, Javascript / Typescript : 0.01
# programming language_ABAP,SAP / ABAP : 0.01
# programming language_Python,Python, Java / Scala, SQL, AWS, Kubernetes, Docker : 0.01
# programming language_R,R, SQL, Google Cloud : 0.01
# programming language_Javascript,PHP, Javascript / Typescript, Dart : 0.01
# programming language_React.js / TypeScript,Unknown : 0.01
# Position_Stuttgart : 0.01
# programming language_Java, JS,Javascript / Typescript, Java / Scala : 0.01
# programming language_Golang ,Javascript / Typescript, .NET, SQL, Go, Kubernetes, Docker : 0.01
# programming language_Unknown,PHP, SQL, AWS, Azure, Kubernetes, Docker : 0.01
# programming language_Erlang,Python, SQL, Docker : 0.01
# programming language_Golang,Python, Ruby, Go, AWS, Google Cloud, Kubernetes, Docker : 0.01
# programming language_Javascript,Javascript / Typescript, SQL, AWS, Docker : 0.01
# programming language_Swift,Java / Scala : 0.01
# Position_Support Engineer : 0.01
# programming language_Javascript ,AWS, Docker : 0.01
# Main language at work_German : 0.01
# programming language_Python ,R, SQL, Hadoop Hive : 0.01
# programming language_PHP,Javascript / Typescript : 0.01
# programming language_Unknown,Python, Kotlin, Javascript / Typescript, Java / Scala, SQL, Kubernetes, Docker : 0.01
# programming language_Ruby,Go, AWS, Kubernetes, Docker, Elixir : 0.01
# City_Karlsruhe : 0.01
# programming language_Java,Javascript / Typescript, Java / Scala, SQL, Docker, Groovy : 0.00
# programming language_Python,SQL, AWS, Azure, Kubernetes, Docker : 0.00
# programming language_Python,Python, Javascript / Typescript, AWS, Docker : 0.00
# programming language_Python,SQL, AWS : 0.00
# Position_Data Center Manager : 0.00
# programming language_Frontend,Javascript / Typescript : 0.00
# programming language_Scala,Javascript / Typescript, Java / Scala, SQL, AWS, Docker : 0.00
# programming language_Linux Kernel,C/C++ : 0.00
# programming language_Typescript,Python, Javascript / Typescript, Java / Scala, SQL, AWS, Google Cloud, Docker : 0.00
# programming language_Web developer,PHP, Javascript / Typescript, SQL, Docker : 0.00
# programming language_TypeScript/Angular,Python, Javascript / Typescript : 0.00
# programming language_C++,Python, C/C++, Javascript / Typescript, Docker : 0.00
# programming language_SQL,Python : 0.00
# programming language_Angular,Javascript / Typescript : 0.00
# programming language_Python,Python, C/C++, Swift, Matlab  : 0.00
# programming language_AWS,Javascript / Typescript, Java / Scala, AWS, Docker : 0.00
# programming language_C#,C/C++, .NET, SQL : 0.00
# programming language_Python,Python, Java / Scala, SQL, AWS : 0.00
# programming language_C++/c,Python, Docker : 0.00
# programming language_Python,C/C++, SQL, Google Cloud, Docker : 0.00
# programming language_Hardware,Unknown : 0.00
# programming language_Js, reactJS ,Javascript / Typescript, AWS : 0.00
# programming language_UML,Unknown : 0.00
# programming language_Java,PHP, Java / Scala, SQL, AWS, Docker : 0.00
# programming language_yaml,Python, AWS, Kubernetes, Docker, terraform, ansible : 0.00
# programming language_Java,Kotlin, SQL, AWS, Kubernetes, Docker : 0.00
# programming language_Python,SQL, Docker, Apache Spark, Apache Hadoop, Oracle, PostgreSQL, Bash, Apache Impala, Apache Hive : 0.00
# programming language_Unknown,Javascript / Typescript, SQL, Go, AWS, Google Cloud, Azure, Kubernetes : 0.00
# programming language_Embedded,C/C++ : 0.00
# programming language_NodeJS,Python, Javascript / Typescript, SQL, AWS, Azure, Kubernetes, Docker : 0.00
# programming language_Python + SQL,Python, SQL, Spark : 0.00
# programming language_TypeScript,Python, Javascript / Typescript, SQL, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Python,R, SQL, AWS, Docker : 0.00
# Position_BI Developer / Data Engineer : 0.00
# programming language_Figma,Unknown : 0.00
# programming language_Nodejs,PHP, Javascript / Typescript : 0.00
# programming language_Python / JavaScript (React),Python, Javascript / Typescript, SQL, AWS, Docker, React, Tailwindcss : 0.00
# programming language_Python ,SQL, AWS, Kubernetes, Docker : 0.00
# programming language_Java,SQL : 0.00
# programming language_C++,Javascript / Typescript, Java / Scala : 0.00
# programming language_Java,SQL, Go, AWS, Kubernetes, Docker : 0.00
# programming language_Python,Python, AWS : 0.00
# programming language_Unknown,AWS : 0.00
# programming language_Android,Kotlin, Java / Scala, Azure : 0.00
# programming language_TypeScript,AWS, Docker : 0.00
# programming language_Android,Kotlin : 0.00
# programming language_C#,Python, PHP, Javascript / Typescript, .NET, Java / Scala, AWS, Azure : 0.00
# programming language_Go,Python, SQL, Go, AWS, Kubernetes, Docker : 0.00
# Position_Mobile Developer : 0.00
# programming language_Python,Python, SQL, Azure : 0.00
# programming language_Python,AWS, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Unknown,PHP, SQL, Perl : 0.00
# programming language_C,Python, C/C++, Docker : 0.00
# programming language_Java,Kotlin, Javascript / Typescript, AWS, Kubernetes, Docker : 0.00
# programming language_Java,Javascript / Typescript, SQL, Docker : 0.00
# programming language_Java,Kotlin, Java / Scala, SQL, AWS : 0.00
# programming language_Python,Python, SQL, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Javascript,Python, Javascript / Typescript, Go : 0.00
# programming language_Python,Python, Azure, Docker : 0.00
# programming language_Kotlin,Python, Ruby : 0.00
# programming language_Pascal, VB.NET, C#,.NET, SQL : 0.00
# programming language_Haskell,Python, C/C++, .NET, SQL : 0.00
# Position_Head of Engineering : 0.00
# programming language_ABAP,SQL, SAP / ABAP : 0.00
# programming language_Node.js,Javascript / Typescript, SQL, Google Cloud, Kubernetes, Docker : 0.00
# programming language_c++,Python, C/C++, Javascript / Typescript, Ruby, .NET, Java / Scala, SQL, Go, AWS, Kubernetes : 0.00
# Position_Technical Lead : 0.00
# programming language_Python,Python, C/C++, Javascript / Typescript, SQL, Docker : 0.00
# Position_Lead Software Developer : 0.00
# programming language_Kubernetes,Python, Go, AWS, Kubernetes, Docker : 0.00
# Position_Engineering Team Lead : 0.00
# programming language_Javascript,Unknown : 0.00
# Position_Student, Software Developer, Data Engineer : 0.00
# programming language_Java & PHP,Python, PHP, Javascript / Typescript, Java / Scala, SQL, AWS, Google Cloud, Kubernetes, Docker : 0.00
# Position_Rentner : 0.00
# programming language_JS,Docker : 0.00
# programming language_Test Management ,Unknown : 0.00
# programming language_Python,Python, Javascript / Typescript, Docker : 0.00
# programming language_TypeScript, JavaScript,Javascript / Typescript, Docker : 0.00
# programming language_Swift, objective-c,Kotlin, Swift, Go, AWS, Kubernetes, Docker : 0.00
# programming language_Unknown,Java / Scala, SQL : 0.00
# programming language_JavaScript / TypeScript,AWS, Docker : 0.00
# programming language_Power BI,Python, Javascript / Typescript, SQL, SAP / ABAP, Google Cloud, Azure : 0.00
# programming language_Kubrrnetes,R, AWS, Google Cloud, Kubernetes, Docker : 0.00
# Position_Software Developer in Test : 0.00
# programming language_C++,Python, C/C++, SQL : 0.00
# programming language_Java,Python, Docker : 0.00
# programming language_Python,Python, SQL, Perl, AWS, Google Cloud, Docker : 0.00
# programming language_Java/C++,Python, C/C++, Javascript / Typescript, Java / Scala, SQL, Kubernetes : 0.00
# Position_Graphic Designer : 0.00
# programming language_Python,SQL, AWS, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Kotlin,Kotlin, Javascript / Typescript, Java / Scala, SQL, AWS, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Python/NLP,Python, AWS, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Scala,Python, Java / Scala, Perl : 0.00
# programming language_JavaScript,Kubernetes, Docker : 0.00
# programming language_SQL,Python, Javascript / Typescript : 0.00
# programming language_Scala,Python, Java / Scala, SQL, Go, AWS, Google Cloud, Kubernetes, Docker : 0.00
# Position_Marketing Analyst : 0.00
# programming language_Python,Javascript / Typescript, SQL, AWS, Kubernetes, Docker : 0.00
# programming language_Terraform ,Python, AWS, Kubernetes : 0.00
# programming language_Java,Javascript / Typescript, SQL, AWS, Docker : 0.00
# programming language_Kotlin,Java / Scala, SQL, AWS, Kubernetes, Docker : 0.00
# programming language_Unknown,AWS, Google Cloud : 0.00
# programming language_Salesforce ,Python, Javascript / Typescript, Apex : 0.00
# programming language_Go,Python, PHP, Javascript / Typescript, Go, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Spark,Python, Docker : 0.00
# programming language_Python, Pytorch,Python, AWS, Google Cloud, Docker : 0.00
# programming language_Bash,Python, Google Cloud : 0.00
# Position_Architect  : 0.00
# programming language_Ruby,SQL, AWS : 0.00
# programming language_PHP ,AWS, Docker : 0.00
# programming language_Python,R, SQL : 0.00
# programming language_Python,Google Cloud : 0.00
# programming language_Scala,Ruby, Java / Scala, AWS, Kubernetes, Docker : 0.00
# programming language_Java,Python, SQL, AWS, Azure, Kubernetes, Docker : 0.00
# programming language_python,Python, C/C++, AWS : 0.00
# programming language_Scala / Python,Python, Ruby, Java / Scala, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Java,Python, Java / Scala, SQL, Go, AWS, Google Cloud, Kubernetes, Docker : 0.00
# programming language_JS,Javascript / Typescript, AWS : 0.00
# programming language_Python,Python, C/C++, SQL, AWS : 0.00
# City_Frankfurt : 0.00
# programming language_Kubernetes, Terraform, GCP,Ruby, AWS, Google Cloud, Docker, Helm, Kustomize, Ansible : 0.00
# programming language_Java,Kotlin, Java / Scala, AWS, Kubernetes, Docker : 0.00
# programming language_Perl,SQL, Go, AWS, Docker : 0.00
# programming language_Java,Javascript / Typescript : 0.00
# programming language_Python,Python, SQL, AWS, Kubernetes, Docker : 0.00
# programming language_Frontend: react, node.js,Javascript / Typescript, AWS, Kubernetes, Docker : 0.00
# programming language_python,Python, C/C++, SQL, Docker : 0.00
# programming language_Python/SQL,AWS, Kubernetes, Docker : 0.00
# Position_SAP BW Senior Consultant  : 0.00
# programming language_java,SQL, AWS, Kubernetes, Docker : 0.00
# programming language_Swift,Unknown : 0.00
# programming language_JavaScript ,Ruby : 0.00
# programming language_Go,Python, Go, AWS, Kubernetes, Docker : 0.00
# programming language_JavaScript,Javascript / Typescript, AWS, Kubernetes, Docker : 0.00
# programming language_C#,PHP, Javascript / Typescript, .NET, SQL, Azure, Kubernetes, Docker, React, Angular2+ : 0.00
# programming language_Swift,Swift : 0.00
# programming language_Python,C/C++, PyTorch : 0.00
# Position_Engineering manager : 0.00
# programming language_Python ,Python, SQL, AWS, Azure, Docker : 0.00
# programming language_React/Typescript,MongoDB : 0.00
# programming language_iOS,Unknown : 0.00
# programming language_Go,Ruby, AWS, Kubernetes, Docker : 0.00
# programming language_JavaScript,Javascript / Typescript : 0.00
# programming language_Python,SQL, Azure : 0.00
# Position_Tech Lead / Full-Stack : 0.00
# programming language_Java,Javascript / Typescript, Java / Scala, AWS, Docker : 0.00
# Position_support engineer : 0.00
# programming language_Scala,Python, SQL, Kubernetes, Docker : 0.00
# programming language_Python,Python, Go, Docker : 0.00
# programming language_Python, SQL,Python, Javascript / Typescript, SQL, AWS, Google Cloud : 0.00
# programming language_Java,Javascript / Typescript, C# : 0.00
# programming language_NodeJS,Javascript / Typescript, SQL, Go, AWS, Kubernetes, Docker, Terraform : 0.00
# programming language_JavaScript / typescript,Unknown : 0.00
# Main language at work_Unknown : 0.00
# programming language_Python, SQL,Python, SQL : 0.00
# programming language_Python,Java / Scala, SQL : 0.00
# programming language_Java, terraform,Python, Kotlin, Javascript / Typescript, Java / Scala, AWS, Kubernetes, Docker : 0.00
# programming language_Python ,Javascript / Typescript, AWS : 0.00
# programming language_C#,.NET, Kubernetes, Docker : 0.00
# programming language_Swift,Swift, Google Cloud : 0.00
# programming language_PHP,PHP, Javascript / Typescript, Java / Scala, Docker : 0.00
# Position_Staff Engineer : 0.00
# programming language_Java,Docker : 0.00
# programming language_Java & Distributed Systems Stuff,Python, Javascript / Typescript, Java / Scala, SQL, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Java ,Python, Javascript / Typescript, AWS, Docker : 0.00
# programming language_C++,Python, C/C++ : 0.00
# Position_Cloud Architect : 0.00
# programming language_SQL,Python, SQL, Google Cloud : 0.00
# City_Berlin : 0.00
# City_Düsseldorf : 0.00
# City_Hamburg : 0.00
# Position_Analytics engineer : 0.00
# Position_Application Consultant : 0.00
# Position_BI Analyst  : 0.00
# Position_BI Consultant : 0.00
# Position_BI IT Consultant : 0.00
# Position_Banker : 0.00
# Position_Beikoch : 0.00
# Position_Business Analyst : 0.00
# Position_Business Development Manager Operations  : 0.00
# Position_CTO : 0.00
# Position_Chief Research Officer : 0.00
# Position_Computational linguist : 0.00
# Position_Consultant  : 0.00
# Position_Consultant Data Analytics : 0.00
# Position_DB developer/Data analyst : 0.00
# Position_Data Analyst  : 0.00
# Position_Data Scientist : 0.00
# Position_Data analyst  : 0.00
# Position_DataOps Team Lead : 0.00
# Position_Designer (UI/UX) : 0.00
# Position_DevOps : 0.00
# Position_ERP Consultant : 0.00
# Position_Firmware Engineer : 0.00
# Position_Full-Stack Developer : 0.00
# Position_Fullstack Developer : 0.00
# Position_Fullstack engineer, ну или Software engineer : 0.00
# Position_Hardware Engineer : 0.00
# Position_Head of BI : 0.00
# Position_HiWi : 0.00
# Position_IT Manager : 0.00
# Position_IT Operations Manager : 0.00
# Position_It Consulting  : 0.00
# Position_Lead Developer : 0.00
# Position_ML Engineer : 0.00
# Position_Manager  : 0.00
# Position_Network Administrator : 0.00
# Position_Network Engineer  : 0.00
# Position_Presales Engineer  : 0.00
# Position_Product Management Praktikant : 0.00
# Position_Product Manager : 0.00
# Position_Professor : 0.00
# Position_Project Manager : 0.00
# Position_Project manager  : 0.00
# Position_QA Lead : 0.00
# Position_QA Manager : 0.00
# Position_Recruiter : 0.00
# Position_Reporting Engineer : 0.00
# Position_Robotics Engineer : 0.00
# Position_SAP Consultant : 0.00
# Position_SAP Developer : 0.00
# Position_SRE : 0.00
# Position_SW Architect : 0.00
# Position_Sales  : 0.00
# Position_Scrum Master : 0.00
# Position_Security Engineer : 0.00
# Position_Security Manager : 0.00
# Position_Security engineer : 0.00
# Position_Senior Data Engineer : 0.00
# Position_Senior Network&Security Eng. : 0.00
# Position_Senior Program Manager : 0.00
# Position_Senior Scrum Master (RTE) : 0.00
# Position_Software Architect : 0.00
# Position_Software Engineer : 0.00
# Position_Software tester  : 0.00
# Position_Solution Architect : 0.00
# Position_Solutions Architect : 0.00
# Position_Solutions architect : 0.00
# Position_Systemadministrator : 0.00
# Position_Team Lead : 0.00
# Position_Teamlead : 0.00
# Position_Technical account manager  : 0.00
# Position_Technical project manager : 0.00
# Position_Test manager : 0.00
# Position_Testautomation : 0.00
# Position_Testmanager : 0.00
# Position_agile master  : 0.00
# Position_computer vision researcher : 0.00
# Position_technical business analyst : 0.00
# Position_working student (QA) : 0.00
# Company size_11-50 : 0.00
# Company size_up to 10 : 0.00
# Company type_Unknown : 0.00
# Company type_other : 0.00
# programming language_--,Unknown : 0.00
# programming language_.NET,Javascript / Typescript, .NET, Azure, Kubernetes, Docker : 0.00
# programming language_.NET,Javascript / Typescript, .NET, SQL, AWS : 0.00
# programming language_.NET,Javascript / Typescript, .NET, SQL, Docker : 0.00
# programming language_.NET,Javascript / Typescript, Java / Scala, SQL : 0.00
# programming language_.NET,Javascript / Typescript, SQL, Azure : 0.00
# programming language_.NET,Kotlin : 0.00
# programming language_.NET,Python, C/C++, .NET : 0.00
# programming language_.NET,Python, Javascript / Typescript, Azure : 0.00
# programming language_.NET,Python, Javascript / Typescript, SQL, AWS, Docker : 0.00
# programming language_.Net, Angular,Javascript / Typescript, .NET, SQL, Azure, Docker : 0.00
# programming language_.Net,.NET, SQL : 0.00
# programming language_.Net,Javascript / Typescript, .NET, SQL, AWS, Azure, Kubernetes, Docker : 0.00
# programming language_.net, c++, spss, embeddded,C/C++, .NET, Go : 0.00
# programming language_.net,.NET : 0.00
# programming language_.net,C/C++, .NET, Go, Docker : 0.00
# programming language_.net,Javascript / Typescript, .NET, SQL, Azure : 0.00
# programming language_.net,Javascript / Typescript, .NET, SQL, Azure, Kubernetes, Docker : 0.00
# programming language_.net,Javascript / Typescript, .NET, SQL, Docker : 0.00
# programming language_ABAP,Javascript / Typescript, SAP / ABAP : 0.00
# programming language_ABAP,Python, SQL : 0.00
# programming language_AI,Python, SQL : 0.00
# programming language_AWS, GCP, Python,K8s,Python, AWS, Google Cloud, Kubernetes, Docker : 0.00
# programming language_AWS,AWS, Azure : 0.00
# programming language_AWS,Python, AWS, Docker : 0.00
# programming language_Android,Kotlin, Java / Scala : 0.00
# programming language_Android,Python, Kotlin, Swift, Javascript / Typescript, Java / Scala, SQL, AWS, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Angular, TypeScript,Javascript / Typescript : 0.00
# programming language_Angular,Javascript / Typescript, Azure, Kubernetes, GraphQL : 0.00
# programming language_Apache Spark,Python, Java / Scala : 0.00
# programming language_Autonomous Driving,C/C++ : 0.00
# programming language_Aws Hadoop Postgre Typescript,Python, Kotlin, Javascript / Typescript, SQL, AWS : 0.00
# programming language_Azure, SAP,SAP / ABAP, AWS, Google Cloud, Azure, Kubernetes, Docker : 0.00
# programming language_Azure,Python, SQL, Azure : 0.00
# programming language_Bash,Python, Java / Scala, SQL, AWS, Azure : 0.00
# programming language_Business Development Manager Operation ,Unknown : 0.00
# programming language_C#, .net core,Python, Javascript / Typescript, .NET, AWS, Azure, Kubernetes, Docker : 0.00
# programming language_C#,C/C++, Javascript / Typescript, .NET, SQL, Azure : 0.00
# programming language_C#,Javascript / Typescript : 0.00
# programming language_C#,Javascript / Typescript, .NET : 0.00
# programming language_C#,Javascript / Typescript, .NET, Azure, Kubernetes, Docker : 0.00
# programming language_C#,Javascript / Typescript, .NET, SQL : 0.00
# programming language_C#,Javascript / Typescript, .NET, SQL, AWS, Docker : 0.00
# programming language_C#,Javascript / Typescript, .NET, SQL, Azure, Docker : 0.00
# programming language_C#,Python, .NET, SQL : 0.00
# programming language_C#,Python, Javascript / Typescript : 0.00
# programming language_C#/.NET,C/C++, SQL, VBA : 0.00
# programming language_C++, C#,C/C++, .NET : 0.00
# programming language_C++,C/C++, PHP, SQL : 0.00
# programming language_C++,Javascript / Typescript : 0.00
# programming language_C++,Python, C/C++, .NET : 0.00
# programming language_C++,Python, C/C++, Docker : 0.00
# programming language_C++,Python, C/C++, Java / Scala : 0.00
# programming language_C++,Python, C/C++, Java / Scala, AWS, Kubernetes, Docker : 0.00
# programming language_C++,Python, C/C++, Javascript / Typescript, SQL : 0.00
# programming language_C++,Python, C/C++, Rust : 0.00
# programming language_C++,Python, C/C++, Rust, AWS, Kubernetes, Docker : 0.00
# programming language_C++,Python, Qt : 0.00
# programming language_C++,Unknown : 0.00
# programming language_C, Matlab,Unknown : 0.00
# programming language_C/C++,C/C++ : 0.00
# programming language_C/C++,Python, C/C++ : 0.00
# programming language_Charles,Unknown : 0.00
# programming language_Cloud,Python, .NET, Azure, Kubernetes, Docker : 0.00
# programming language_Cobol,Perl : 0.00
# programming language_Computer Networking,  Network Security ,SQL : 0.00
# programming language_DC Management,Unknown : 0.00
# programming language_DWH,SQL : 0.00
# programming language_Django, Flask, Plotly Dash,Python, AWS : 0.00
# programming language_Embedded,Python, C/C++, Go : 0.00
# programming language_GCP,Python, Java / Scala, R, SQL, Google Cloud : 0.00
# programming language_Go, PHP, SQL,PHP, SQL, Go, AWS, Docker : 0.00
# programming language_Go,Go : 0.00
# programming language_Go,Go, AWS, Docker : 0.00
# programming language_Go,Google Cloud, Docker : 0.00
# programming language_Go,Java / Scala, AWS, Docker : 0.00
# programming language_Go,Java / Scala, Go, AWS, Google Cloud, Azure, Kubernetes, Docker : 0.00
# programming language_Go,Kotlin, Ruby, Go, Rust, AWS, Kubernetes, Docker : 0.00
# programming language_Go,PHP, AWS, Kubernetes, Docker : 0.00
# programming language_Go,PHP, Go : 0.00
# programming language_Go,PHP, Java / Scala, Go, AWS, Docker : 0.00
# programming language_Go,Python : 0.00
# programming language_Go,Python, C/C++, Go, AWS, Docker : 0.00
# programming language_Go,Python, Javascript / Typescript, Go : 0.00
# programming language_Go,Python, PHP, AWS, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Go,Python, SQL, Go : 0.00
# programming language_Go,SQL, AWS, Docker : 0.00
# programming language_Google Cloud Platform,Python, SQL, Go, Google Cloud, bash : 0.00
# programming language_Grails, Groovy,Java / Scala, SQL, AWS : 0.00
# programming language_JS, Java,Docker : 0.00
# programming language_JS, WDIO,Javascript / Typescript, SQL, Docker : 0.00
# programming language_JS,C/C++, Javascript / Typescript, AWS, Google Cloud, Kubernetes : 0.00
# programming language_JS,Javascript / Typescript, SQL : 0.00
# programming language_JS,Javascript / Typescript, SQL, Docker : 0.00
# programming language_JS,Python, PHP, Javascript / Typescript, SQL, AWS : 0.00
# programming language_JS,Ruby, SQL : 0.00
# programming language_JS,Unknown : 0.00
# programming language_JavScript,Javascript / Typescript, AWS, Docker : 0.00
# programming language_Java ,Kotlin, Java / Scala : 0.00
# programming language_Java, .Net,.NET, Java / Scala, SQL, Go, AWS, Docker : 0.00
# programming language_Java, JavaScript,Javascript / Typescript, Java / Scala, SQL : 0.00
# programming language_Java, Javascript,Javascript / Typescript : 0.00
# programming language_Java, angular, Aws,Python, Javascript / Typescript, Java / Scala, SQL, AWS, Docker : 0.00
# programming language_Java,AWS : 0.00
# programming language_Java,C/C++, Kubernetes, Docker : 0.00
# programming language_Java,Go, AWS, Kubernetes : 0.00
# programming language_Java,Go, AWS, Kubernetes, Docker : 0.00
# programming language_Java,Java / Scala : 0.00
# programming language_Java,Java / Scala, AWS, Kubernetes, Docker : 0.00
# programming language_Java,Java / Scala, Google Cloud, Kubernetes : 0.00
# programming language_Java,Java / Scala, SQL : 0.00
# programming language_Java,Javascript / Typescript, .NET, SQL : 0.00
# programming language_Java,Javascript / Typescript, Java / Scala : 0.00
# programming language_Java,Javascript / Typescript, Java / Scala, Go, AWS, Docker : 0.00
# programming language_Java,Javascript / Typescript, Java / Scala, SQL : 0.00
# programming language_Java,Javascript / Typescript, Java / Scala, SQL, AWS, Docker, nomad, QlikSense : 0.00
# programming language_Java,Javascript / Typescript, Java / Scala, SQL, AWS, Kubernetes, Docker : 0.00
# programming language_Java,Javascript / Typescript, Java / Scala, SQL, Docker : 0.00
# programming language_Java,Javascript / Typescript, SQL : 0.00
# programming language_Java,Javascript / Typescript, SQL, Go, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Java,Kotlin, C/C++, Javascript / Typescript, Java / Scala, AWS, Docker : 0.00
# programming language_Java,Kotlin, Java / Scala, SQL : 0.00
# programming language_Java,Kotlin, Java / Scala, SQL, AWS, Docker : 0.00
# programming language_Java,Kotlin, Java / Scala, SQL, Kubernetes, Docker : 0.00
# ...
# programming language_Management,Unknown : 0.00
# programming language_Ml/Python,Python, AWS, Docker : 0.00
# programming language_NLP, Python,Python, C/C++, Google Cloud, Docker : 0.00
# programming language_Node,Python, PHP, SQL : 0.00
# programming language_Node.js,Javascript / Typescript, Google Cloud, Kubernetes : 0.00
# programming language_NodeJS/TS,Javascript / Typescript : 0.00
# programming language_NodsJs,Javascript / Typescript, AWS, Kubernetes, Docker : 0.00
# programming language_Objective-C,Swift : 0.00
# programming language_Oracle,SQL : 0.00
# programming language_PHP ,Python, Javascript / Typescript, .NET, SQL, AWS, Azure, Kubernetes, Docker : 0.00
# programming language_PHP,Javascript / Typescript, .NET, SQL, Azure, Kubernetes, Docker : 0.00
# programming language_PHP,Javascript / Typescript, Docker : 0.00
# programming language_PHP,Javascript / Typescript, Go, AWS, Google Cloud, Docker : 0.00
# programming language_PHP,Javascript / Typescript, Java / Scala, AWS, Kubernetes, Docker : 0.00
# programming language_PHP,Javascript / Typescript, Kubernetes, Docker : 0.00
# programming language_PHP,Javascript / Typescript, SQL, AWS, Docker : 0.00
# programming language_PHP,Javascript / Typescript, SQL, Docker : 0.00
# programming language_PHP,Kotlin : 0.00
# programming language_PHP,Kotlin, AWS, Kubernetes, Docker : 0.00
# programming language_PHP,Kotlin, Java / Scala, SQL, AWS, Docker : 0.00
# programming language_PHP,PHP, Java / Scala : 0.00
# programming language_PHP,PHP, Javascript / Typescript, AWS, Docker : 0.00
# programming language_PHP,PHP, Javascript / Typescript, Go, AWS, Google Cloud, Kubernetes, Docker : 0.00
# programming language_PHP,Python, C/C++, Javascript / Typescript, Java / Scala, Perl, AWS, Docker, Networking, Data Center : 0.00
# programming language_PHP,Python, C/C++, Javascript / Typescript, SQL, Go, AWS, Docker : 0.00
# programming language_PHP,Python, Javascript / Typescript, Ruby, Java / Scala, AWS, Kubernetes, Docker : 0.00
# programming language_PHP,Python, Javascript / Typescript, SQL, AWS, Google Cloud, Docker : 0.00
# programming language_PHP,Python, PHP, Javascript / Typescript, SQL, AWS, Kubernetes, Docker : 0.00
# programming language_PHP,SQL : 0.00
# programming language_PHP,SQL, AWS, Docker : 0.00
# programming language_PHP/MySQL,PHP, SQL, Docker, VMs : 0.00
# programming language_PL/SQL,SQL : 0.00
# programming language_PM tools,Unknown : 0.00
# programming language_PS, Sketch, React, CSS3,Javascript / Typescript : 0.00
# programming language_Pegasystems platform ,C/C++, Javascript / Typescript, Java / Scala, SQL, Docker : 0.00
# programming language_Php,PHP : 0.00
# programming language_Php,PHP, SQL, Go, AWS, Docker : 0.00
# programming language_Pyrhon,Python, SQL, AWS, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Python (Django),Python, Javascript / Typescript, SQL, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Python ,Java / Scala, R, SQL, Docker, Julia  : 0.00
# programming language_Python ,Python, Go : 0.00
# programming language_Python ,Python, Java / Scala : 0.00
# programming language_Python ,Python, Javascript / Typescript, SQL, Docker : 0.00
# programming language_Python ,Python, Javascript / Typescript, SQL, Go, AWS, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Python ,Python, SQL, AWS : 0.00
# programming language_Python ,SQL, AWS, Google Cloud, Docker : 0.00
# programming language_Python ,SQL, Google Cloud, Docker : 0.00
# programming language_Python, cloud computing ,Python, SQL, AWS, Azure : 0.00
# programming language_Python, database technologies,Python, Java / Scala, SQL, AWS : 0.00
# programming language_Python,AWS, Kubernetes, Docker : 0.00
# programming language_Python,C/C++ : 0.00
# programming language_Python,C/C++, Javascript / Typescript : 0.00
# programming language_Python,C/C++, SQL, AWS, Docker : 0.00
# programming language_Python,C/C++, SQL, Docker : 0.00
# programming language_Python,C/C++, SQL, Go, Rust, AWS, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Python,Docker : 0.00
# programming language_Python,Go, AWS, Kubernetes, Docker : 0.00
# programming language_Python,Java / Scala, AWS, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Python,Java / Scala, SQL, AWS : 0.00
# programming language_Python,Java / Scala, SQL, AWS, Azure : 0.00
# programming language_Python,Java / Scala, SQL, Kubernetes, Docker : 0.00
# programming language_Python,Javascript / Typescript, Google Cloud, Docker : 0.00
# programming language_Python,Javascript / Typescript, R, SQL, AWS, Azure, Docker : 0.00
# programming language_Python,Javascript / Typescript, R, SQL, Google Cloud : 0.00
# programming language_Python,Javascript / Typescript, SQL : 0.00
# programming language_Python,Python, .NET, Azure : 0.00
# programming language_Python,Python, AWS, Kubernetes, Docker : 0.00
# programming language_Python,Python, C/C++, Azure, Docker : 0.00
# programming language_Python,Python, C/C++, Docker : 0.00
# programming language_Python,Python, C/C++, Docker, Tensorflow, PyTorch : 0.00
# programming language_Python,Python, C/C++, Java / Scala, AWS, Azure, spark : 0.00
# programming language_Python,Python, C/C++, Pytorch : 0.00
# programming language_Python,Python, C/C++, SQL, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Python,Python, Docker : 0.00
# programming language_Python,Python, Java / Scala, SQL, AWS, Docker : 0.00
# programming language_Python,Python, Java / Scala, SQL, Google Cloud : 0.00
# programming language_Python,Python, Javascript / Typescript, Java / Scala, SQL, AWS, Kubernetes, Docker : 0.00
# programming language_Python,Python, Javascript / Typescript, Perl, AWS, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Python,Python, Javascript / Typescript, SQL, Docker : 0.00
# programming language_Python,Python, Javascript / Typescript, SQL, Google Cloud : 0.00
# programming language_Python,Python, PHP, Javascript / Typescript, SQL, Docker : 0.00
# programming language_Python,Python, R : 0.00
# programming language_Python,Python, R, Docker : 0.00
# programming language_Python,Python, R, Google Cloud, Docker : 0.00
# programming language_Python,Python, R, SQL : 0.00
# programming language_Python,Python, R, SQL, Google Cloud : 0.00
# programming language_Python,Python, R, Spark : 0.00
# programming language_Python,Python, SQL : 0.00
# programming language_Python,Python, SQL, AWS, Docker : 0.00
# programming language_Python,Python, SQL, AWS, Docker, Spark, Airflow : 0.00
# programming language_Python,Python, SQL, Azure, Docker : 0.00
# programming language_Python,Python, SQL, SAP / ABAP, AWS : 0.00
# programming language_Python,Python, Tensorflow, Theano, Pytorch : 0.00
# programming language_Python,R, AWS : 0.00
# programming language_Python,R, SQL, AWS : 0.00
# programming language_Python,R, SQL, AWS, Google Cloud : 0.00
# programming language_Python,Ruby, SQL : 0.00
# programming language_Python,SQL : 0.00
# programming language_Python,SQL, AWS, Docker : 0.00
# programming language_Python,SQL, AWS, Docker, Matlab : 0.00
# programming language_Python,SQL, Docker : 0.00
# programming language_Python,SQL, Go : 0.00
# programming language_Python,SQL, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Python,SQL, Kubernetes, Docker : 0.00
# programming language_QA,Java / Scala : 0.00
# programming language_QA,Python : 0.00
# programming language_QA,Python, SQL : 0.00
# programming language_QA,Unknown : 0.00
# programming language_Qlik BI Tool, SQL,Javascript / Typescript, SQL : 0.00
# programming language_Qlik,SQL : 0.00
# programming language_R,Python : 0.00
# programming language_R,Python, R, SQL : 0.00
# programming language_R,Python, SQL : 0.00
# programming language_React ,Javascript / Typescript : 0.00
# programming language_React,Javascript / Typescript : 0.00
# programming language_React,Python, AWS, Kubernetes, Docker, React : 0.00
# programming language_Ruby on Rails,Javascript / Typescript : 0.00
# programming language_Ruby on Rails,Python, Kotlin, Ruby, AWS, Docker : 0.00
# programming language_Ruby,Elixir : 0.00
# programming language_Ruby,Go : 0.00
# programming language_Ruby,Java / Scala, SQL : 0.00
# programming language_Ruby,Javascript / Typescript, AWS, Docker : 0.00
# programming language_Ruby,Javascript / Typescript, Ruby, AWS, Docker : 0.00
# programming language_Ruby,Javascript / Typescript, SQL, Go, AWS, Docker : 0.00
# programming language_Ruby,Kotlin, Javascript / Typescript, Java / Scala : 0.00
# programming language_Ruby,Kotlin, PHP, Ruby, Java / Scala, SQL, AWS, Kubernetes, Docker : 0.00
# programming language_Ruby,Python, Javascript / Typescript, Ruby, SQL, AWS, Docker : 0.00
# programming language_SAP ABAP,SAP / ABAP : 0.00
# programming language_SAP,SAP / ABAP : 0.00
# programming language_SAS,SQL,Python,Python, SQL, SAS : 0.00
# programming language_SQL,Python, Clojure, SQL : 0.00
# programming language_SQL,Python, Javascript / Typescript, .NET, Java / Scala, SQL, Go, AWS, Azure, Docker : 0.00
# programming language_SQL,Python, Javascript / Typescript, Google Cloud : 0.00
# programming language_SQL,Python, Javascript / Typescript, Ruby, AWS : 0.00
# programming language_Scala, Apache Spark,Java / Scala, SQL, AWS, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Scala,Go, Google Cloud : 0.00
# programming language_Scala,Java / Scala, AWS, Kubernetes : 0.00
# programming language_Scala,Java / Scala, SQL, AWS, Kubernetes, Docker : 0.00
# programming language_Scala,Java / Scala, SQL, Google Cloud, Docker : 0.00
# programming language_Scala,Python, Java / Scala : 0.00
# programming language_Scala,Python, Java / Scala, AWS, Docker : 0.00
# programming language_Scala,Python, Java / Scala, Docker : 0.00
# programming language_Scala,Python, Java / Scala, SQL, AWS, Google Cloud, Azure : 0.00
# programming language_Scala,Python, Javascript / Typescript, Java / Scala, AWS, Kubernetes : 0.00
# programming language_Scala,Python, Kotlin, Java / Scala, SQL, Kubernetes, Docker : 0.00
# programming language_Sketch, Figma,Unknown : 0.00
# programming language_Spark, Pytorch,Python : 0.00
# programming language_Spring,Java / Scala, AWS, Azure, Kubernetes, Docker : 0.00
# programming language_Sql ,Python : 0.00
# programming language_Sql ,Python, R, SQL, Google Cloud : 0.00
# programming language_Swift, Objective-C, iOS,Swift : 0.00
# programming language_Swift,Kotlin, Ruby : 0.00
# programming language_Swift,Kotlin, Swift, Ruby : 0.00
# programming language_Swift,Python, Kotlin, Swift, Javascript / Typescript : 0.00
# programming language_Swift/Kotlin,Kotlin, Javascript / Typescript, SQL, AWS, Docker : 0.00
# programming language_TS,Unknown : 0.00
# programming language_Terraform,PHP, SQL, AWS, Docker : 0.00
# programming language_Tricentis Tosca,Java / Scala, SQL : 0.00
# programming language_TypeScript, Kotlin,Kotlin, Javascript / Typescript, Rust : 0.00
# programming language_TypeScript,Javascript / Typescript, AWS : 0.00
# programming language_TypeScript,Javascript / Typescript, Kubernetes : 0.00
# programming language_TypeScript,Python, Kotlin, Javascript / Typescript, SQL, AWS, Docker : 0.00
# programming language_Typescript / Angular,Unknown : 0.00
# programming language_Typescript, Web apps,Javascript / Typescript : 0.00
# programming language_Typescript,Java / Scala : 0.00
# programming language_Typescript,Java / Scala, Kubernetes, Docker : 0.00
# programming language_Typescript,Javascript / Typescript : 0.00
# programming language_Typescript,Javascript / Typescript, .NET, C#, Angular  : 0.00
# programming language_Typescript,Javascript / Typescript, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Unknown,Azure : 0.00
# programming language_Unknown,Bi : 0.00
# programming language_Unknown,Clojure, Rust : 0.00
# programming language_Unknown,Figma, Sketch, Photoshop, etc... : 0.00
# programming language_Unknown,Javascript / Typescript : 0.00
# programming language_Unknown,Javascript / Typescript, Ruby, Elixir : 0.00
# programming language_Unknown,Kotlin, Java / Scala, SQL, AWS, Kubernetes, Docker : 0.00
# programming language_Unknown,PHP : 0.00
# programming language_Unknown,Python : 0.00
# programming language_Unknown,Python, C/C++, AWS, Kubernetes, Docker : 0.00
# programming language_Unknown,Python, Go, AWS, Kubernetes, Docker : 0.00
# programming language_Unknown,Python, Javascript / Typescript, Java / Scala, SQL : 0.00
# programming language_Unknown,Python, PHP, SQL, Perl, AWS, Google Cloud, Kubernetes, Docker : 0.00
# programming language_Unknown,Python, R, Go : 0.00
# programming language_Unknown,Python, R, SQL, AWS, Google Cloud, Azure, Docker : 0.00
# programming language_Unknown,Python, SQL, AWS, Google Cloud, Docker : 0.00
# programming language_Unknown,Python, SQL, AWS, Kubernetes, Docker : 0.00
# programming language_Unknown,Python, SQL, Go, AWS, Kubernetes, Docker : 0.00
# programming language_Unknown,Ruby, SQL, Go, AWS, Kubernetes, Docker : 0.00
# programming language_Unknown,SQL, AWS, Kubernetes : 0.00
# programming language_VB, RPA, Python,Python, PHP, Javascript / Typescript, .NET, SQL, SAP / ABAP : 0.00
# programming language_android,Kotlin : 0.00
# programming language_c++,C/C++, SAP / ABAP : 0.00
# programming language_c/c++,Python : 0.00
# programming language_embedded,C/C++, Clojure, Assembly : 0.00
# programming language_go,PHP, Javascript / Typescript, Perl, AWS, Kubernetes, Docker : 0.00
# programming language_iOS,Swift, AWS : 0.00
# programming language_iOS,Swift, Flutter : 0.00
# programming language_java,AWS, Docker : 0.00
# programming language_java,Kotlin : 0.00
# programming language_java,Kubernetes, Docker : 0.00
# programming language_java,PHP : 0.00
# programming language_java,Python : 0.00
# programming language_java,Unknown : 0.00
# programming language_java/scala/go/clouds/devops,Java / Scala, Go, AWS, Google Cloud, Kubernetes, Docker : 0.00
# programming language_javascript,AWS, Docker : 0.00
# programming language_javascript,Javascript / Typescript, SAP / ABAP : 0.00
# programming language_javascript,Javascript / Typescript, SQL, AWS, Docker : 0.00
# programming language_jenkins bash,Kotlin, Swift, Javascript / Typescript, Docker : 0.00
# programming language_js,Java / Scala, Google Cloud, Docker : 0.00
# programming language_nothing,Python : 0.00
# programming language_php, js, python, docker,SQL, AWS, Azure : 0.00
# programming language_php,Javascript / Typescript, Docker : 0.00
# programming language_php,PHP, Javascript / Typescript, SQL : 0.00
# programming language_php,PHP, Javascript / Typescript, SQL, Docker : 0.00
# programming language_php,PHP, SQL, Docker : 0.00
# programming language_php,PHP, SQL, Go, Docker, Postgres : 0.00
# programming language_php,Python, PHP, Javascript / Typescript, SQL : 0.00
# programming language_php,SQL, Google Cloud, Docker : 0.00
# programming language_pythin,Python, SQL, Docker : 0.00
# programming language_python ,Python, Javascript / Typescript, Ruby, SQL : 0.00
# programming language_python,Google Cloud : 0.00
# programming language_python,Javascript / Typescript, AWS, Kubernetes : 0.00
# programming language_python,Javascript / Typescript, Java / Scala, Docker : 0.00
# programming language_python,Python : 0.00
# programming language_python,Python, AWS, Docker : 0.00
# programming language_python,Python, Docker : 0.00
# programming language_python,Python, Java / Scala, AWS : 0.00
# programming language_python,Python, Javascript / Typescript, SQL, Go, AWS, Google Cloud, Kubernetes, Docker : 0.00
# programming language_python,Python, R, SQL, SAP / ABAP, AWS, Kubernetes, Docker : 0.00
# programming language_python,Python, SQL, AWS, Google Cloud : 0.00
# programming language_python,SQL, AWS, Docker : 0.00
# programming language_ruby on rails,Javascript / Typescript, Ruby, SQL : 0.00
# programming language_scala,Java / Scala : 0.00
# programming language_several,Python, SQL, AWS, Docker, unix shell scripts : 0.00
# programming language_sql,Python, R, SQL : 0.00
# programming language_swift,SQL : 0.00
# programming language_typescript,Javascript / Typescript, .NET, Azure : 0.00
# programming language_yaml,Python, PHP, Javascript / Typescript, SQL, Go, Perl, AWS, Google Cloud, Azure, Kubernetes, Docker : 0.00
# programming language_Офмф,Unknown : 0.00
# programming language_С#,Python, C/C++, Javascript / Typescript, .NET, SQL : 0.00

# %% [markdown]
# <b> Pipeline 3, 4 with feature selection from above

# %%
fsy = dfm['total salary']
fsx = x[new_features]
fsx_train, fsx_test, fsy_train, fsy_test = train_test_split(fsx, fsy, test_size = 0.3, random_state = 0)

et_pipeline = make_pipeline(VarianceThreshold(.2), StandardScaler(), ExtraTreesRegressor())
rf_pipeline = make_pipeline(VarianceThreshold(.2), StandardScaler(), RandomForestRegressor())


# Fit the pipelines on the new data
et_pipeline.fit(fsx, fsy)
rf_pipeline.fit(fsx, fsy)
# Out:
# Pipeline(steps=[('variancethreshold', VarianceThreshold(threshold=0.2)),
#                 ('standardscaler', StandardScaler()),
#                 ('randomforestregressor', RandomForestRegressor())])

# %%
# ExtraTreeRegressor
fsy_pred3 = et_pipeline.predict(fsx_test)
cv3 = cross_val_score(ExtraTreeRegressor(), fsx, fsy, cv = 5)

print('Training set accuracy: {:.2f}'.format(et_pipeline.score(fsx_train, fsy_train)))
print('Testing set accuracy: {:.2f}'.format(et_pipeline.score(fsx_test, fsy_test)))
print('RMSE: {:.2f}'.format(np.sqrt(mean_squared_error(fsy_test, fsy_pred3))))
print('R2: {:.2f}'.format(r2_score(fsy_test, fsy_pred3)))
print('Cross Validation score: {:.2f}'.format(cv3.mean()))
# Out:
# Training set accuracy: 0.98
# Testing set accuracy: 0.99
# RMSE: 2913.17
# R2: 0.99
# Cross Validation score: -0.68

# %%
# RandomForestRegressor
fsy_pred4 = rf_pipeline.predict(fsx_test)
cv4 = cross_val_score(RandomForestRegressor(), fsx, fsy, cv = 5)

print('Training set accuracy: {:.2f}'.format(rf_pipeline.score(fsx_train, fsy_train)))
print('Testing set accuracy: {:.2f}'.format(rf_pipeline.score(fsx_test, fsy_test)))
print('RMSE: {:.2f}'.format(np.sqrt(mean_squared_error(fsy_test, fsy_pred4))))
print('R2: {:.2f}'.format(r2_score(fsy_test, fsy_pred4)))
print('Cross Validation score: {:.2f}'.format(cv4.mean()))
# Out:
# Training set accuracy: 0.86
# Testing set accuracy: 0.87
# RMSE: 13311.18
# R2: 0.87
# Cross Validation score: 0.02

# %% [markdown]
# <b> Define Hyperparameters and Grid Search CV to look better model. (Extra Tree regressor, Random Forest Regressor)

# %%
fsy = dfm['total salary']
fsx = x[new_features]
fsx_train, fsx_test, fsy_train, fsy_test = train_test_split(fsx, fsy, test_size = 0.3, random_state = 0)

# %%
param_grid1 = {
    'extratreesregressor__n_estimators': [50, 100, 200],
    'extratreesregressor__max_depth': [5, 10, 15],
    'extratreesregressor__min_samples_leaf': [1, 2, 3, 4, 5],
}

# %%
# param_grid1
et_pipeline = make_pipeline(VarianceThreshold(.2), StandardScaler(), ExtraTreesRegressor())

grid = GridSearchCV(et_pipeline, param_grid = param_grid1, cv = 5, n_jobs=-1) 
grid.fit(fsx_train, fsy_train)


fsy_pred = grid.best_estimator_.predict(fsx_test)
cv5 = cross_val_score(ExtraTreesRegressor(), fsx, fsy, cv = 5)
best = grid.best_estimator_

# %%
print('best hyperparameters:', grid.best_params_)
print('score: {:.2f}'. format(grid.best_score_))

print('\nTraining set accuracy: {:.2f}'.format(best.score(fsx_train, fsy_train)))
print('R2 score: {:.2f}'.format(best.score(fsx_test, fsy_test)))
print('RMSE: {:.2f}'.format(np.sqrt(mean_squared_error(fsy_test, fsy_pred))))
print('Cross Validation score: {:.2f}'.format(cv5.mean()))
# Out:
# best hyperparameters: {'extratreesregressor__max_depth': 5, 'extratreesregressor__min_samples_leaf': 4, 'extratreesregressor__n_estimators': 200}
# score: 0.18
#
# Training set accuracy: 0.26
# R2 score: 0.12
# RMSE: 34282.95
# Cross Validation score: -0.07

# %%
param_grid2 = {
    'randomforestregressor__n_estimators': [50, 100, 200],
    'randomforestregressor__max_depth': [5, 10, 15],
    'randomforestregressor__min_samples_leaf': [1, 2, 3, 4, 5],
}

# %%
# param_grid2
rf_pipeline = make_pipeline(VarianceThreshold(.2), StandardScaler(), RandomForestRegressor())

grid = GridSearchCV(rf_pipeline, param_grid = param_grid2, cv = 5, n_jobs=-1) 
grid.fit(fsx_train, fsy_train)


fsy_pred = grid.best_estimator_.predict(fsx_test)
cv6 = cross_val_score(RandomForestRegressor(), fsx, fsy, cv = 5)
best = grid.best_estimator_

# %%
print('best hyperparameters:', grid.best_params_)
print('score: {:.2f}'. format(grid.best_score_))

print('\nTraining set accuracy: {:.2f}'.format(best.score(fsx_train, fsy_train)))
print('R2 score: {:.2f}'.format(best.score(fsx_test, fsy_test)))
print('RMSE: {:.2f}'.format(np.sqrt(mean_squared_error(fsy_test, fsy_pred))))
print('Cross Validation score: {:.2f}'.format(cv6.mean()))
# Out:
# best hyperparameters: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 5, 'randomforestregressor__n_estimators': 50}
# score: 0.18
#
# Training set accuracy: 0.32
# R2 score: 0.17
# RMSE: 33441.99
# Cross Validation score: 0.02

# %% [markdown]
# # Answers and Explainations
# - in the total salary column, there were some outliers after the combined salary, bonus and stocks columns.
# - dropped these columns: 'Number of vacation days', 'Employment status', 'Сontract duration'
# - checked the rest of the other columns and deleted a few rows for data wrangling. (1212 rows, 12 columns)
# - for categorical data, models used Extra Tree regressor and Random Forest Regressor for all the setups.
# - since all the missing values and null values were done, the scaler can be chosen StandardScaler.
# - for categorical data, this data set used ExtraTreeRegressor and RandomForestRegressor
# - for feature selection, VarianceThreshold and mutual_info_regression were used. Comparing both results, they had similar columns and a couple of different column orders.
# - in hyperparameter changes, estimators were from 50 to 500, the result shows the best was between 100-200. The maxmium depth was not over 20, and the minimum sample leaf was not over 5.
#
#
# ### Results
# - the results for both regressors were really bad without feature selection and hyperparameter changes. After feature selection, the most relevant features for the prediction can actually improve the model performance.
# - As the R2 score increased to 0.99 and 0.87, there probably had overfitting issues during the process.
# - used the same Hyperparameter settings for both regressors, the RandomForestRegressor had slightly better performance.
# - the RandomForestRegressor model with Feature Selection and Hyperparameter Changes was the better model.
#
#
#
# -- without feature selection and hyperparameters
# - Extra Tree regressor
#
#     training data accuracy <1.00>, RMSE <38013.45>, R2 <-0.08>, CV_score <0.00>
#
# - Random Forest Regressor
#
#     training data accuracy <0.81>, RMSE <34257.57>, R2 <0.12>, CV_score <0.16>
#
# ### Feature Selection Activities
# -- with feature selection
# - Extra Tree regressor
#
#     training data accuracy <0.98>, RMSE <2913.17>, R2 <0.99>, CV_score <-0.68>
#
# - Random Forest Regressor
#
#     training data accuracy <0.86>, RMSE <13311.18>, R2 <0.87>, CV_score <0.02>
#
# ### Hyperparameter Changes
# -- with feature selection and Hyperparameter Changes
# - Extra Tree regressor
#
#     training data accuracy <0.26>, RMSE <34282.85>, R2 <0.12>, CV_score <-0.07>
#
# - Random Forest Regressor
#
#     training data accuracy <0.32>, RMSE <33341.99>, R2 <0.17>, CV_score <0.02>
